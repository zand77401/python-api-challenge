# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import requests
from random import uniform 
from pprint import pprint
from citipy import citipy
import pandas as pd
import os
import csv
import matplotlib.pyplot as plt

# Remember to update the config file with your API key
from config import api_key

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# ## Generate Cities List

# %%
cities = []
duplicate_cities = []

cities_name = []
latitudes = []
longititudes = []
max_temps = []
humidities = []
clouds = []
wind_speeds = []
countries = []
dates = []


print("Beginning Data Retrieval")
print("*"*40)

while len(cities_name) < 500:
    
    # generate a 500 unique latitude and longitude values
    
    long = round(uniform(-180,180), 3) #longitude ranges from -180 to 180
    lat = round(uniform(-90, 90), 3) #latitude ranges from -90 to 90
    #feed into citipy the lat, long coordinates to return as city object
    city = citipy.nearest_city(lat, long)
    city_name = city.city_name
    country_code = city.country_code
    # add the city and it's country code to the cities set
    city_entry = f"{city_name},{country_code}"
    if city_entry not in cities:
        cities.append(city_entry)
        print(f"city generated: {city_entry}")
        query_url = url + "appid=" + api_key + "&q=" + city_entry + "?" + "&units=imperial"
        print(f"processing request for {city_entry}")

        weather_json = requests.get(query_url).json()
        if weather_json['cod'] == 200:
            cities_name.append(weather_json['name'])
            latitudes.append(weather_json['coord']['lat'])
            longititudes.append(weather_json['coord']['lon'])
            max_temps.append(weather_json['main']['temp_max'])
            humidities.append(weather_json['main']['humidity'])
            clouds.append(weather_json['clouds']['all'])
            wind_speeds.append(weather_json['wind']['speed'])
            countries.append(weather_json['sys']['country'])
            dates.append(weather_json['dt'])        
        else:
            print("City not found...skipping. \n")
            pass
    else:
        print(f"duplicate city: {city_entry}")
        duplicate_cities.append(city_entry)

print("*"*40)
print("End of Data Retrieval")
# Out:
# Beginning Data Retrieval
# ****************************************
# city generated: tsihombe,mg
# processing request for tsihombe,mg
# City not found...skipping.
#
# city generated: thompson,ca
# processing request for thompson,ca
# city generated: saskylakh,ru
# processing request for saskylakh,ru
# city generated: jacareacanga,br
# processing request for jacareacanga,br
# city generated: ushuaia,ar
# processing request for ushuaia,ar
# city generated: galveston,us
# processing request for galveston,us
# city generated: rikitea,pf
# processing request for rikitea,pf
# city generated: edd,er
# processing request for edd,er
# city generated: punta arenas,cl
# processing request for punta arenas,cl
# city generated: albany,au
# processing request for albany,au
# city generated: arraial do cabo,br
# processing request for arraial do cabo,br
# city generated: hithadhoo,mv
# processing request for hithadhoo,mv
# city generated: busselton,au
# processing request for busselton,au
# city generated: dikson,ru
# processing request for dikson,ru
# duplicate city: albany,au
# duplicate city: arraial do cabo,br
# city generated: bajmok,rs
# processing request for bajmok,rs
# city generated: atasu,kz
# processing request for atasu,kz
# city generated: kapaa,us
# processing request for kapaa,us
# city generated: saleaula,ws
# processing request for saleaula,ws
# City not found...skipping.
#
# city generated: kyzyl-suu,kg
# processing request for kyzyl-suu,kg
# duplicate city: albany,au
# city generated: saldanha,za
# processing request for saldanha,za
# city generated: san quintin,mx
# processing request for san quintin,mx
# city generated: geraldton,au
# processing request for geraldton,au
# city generated: barrow,us
# processing request for barrow,us
# city generated: cape town,za
# processing request for cape town,za
# city generated: halalo,wf
# processing request for halalo,wf
# City not found...skipping.
#
# city generated: bantry,ie
# processing request for bantry,ie
# city generated: ribeira grande,pt
# processing request for ribeira grande,pt
# city generated: jamestown,sh
# processing request for jamestown,sh
# city generated: tuktoyaktuk,ca
# processing request for tuktoyaktuk,ca
# city generated: touros,br
# processing request for touros,br
# duplicate city: barrow,us
# duplicate city: punta arenas,cl
# city generated: evinayong,gq
# processing request for evinayong,gq
# city generated: saint-philippe,re
# processing request for saint-philippe,re
# city generated: harper,lr
# processing request for harper,lr
# city generated: anaco,ve
# processing request for anaco,ve
# city generated: broome,au
# processing request for broome,au
# city generated: laukaa,fi
# processing request for laukaa,fi
# city generated: kodiak,us
# processing request for kodiak,us
# city generated: korla,cn
# processing request for korla,cn
# city generated: artyk,ru
# processing request for artyk,ru
# City not found...skipping.
#
# duplicate city: ushuaia,ar
# duplicate city: punta arenas,cl
# city generated: charlestown,kn
# processing request for charlestown,kn
# city generated: grand river south east,mu
# processing request for grand river south east,mu
# City not found...skipping.
#
# city generated: hastings,nz
# processing request for hastings,nz
# city generated: longyearbyen,sj
# processing request for longyearbyen,sj
# city generated: aklavik,ca
# processing request for aklavik,ca
# city generated: phuket,th
# processing request for phuket,th
# city generated: severo-kurilsk,ru
# processing request for severo-kurilsk,ru
# city generated: khapa,in
# processing request for khapa,in
# city generated: illoqqortoormiut,gl
# processing request for illoqqortoormiut,gl
# City not found...skipping.
#
# city generated: port hardy,ca
# processing request for port hardy,ca
# city generated: rondonopolis,br
# processing request for rondonopolis,br
# city generated: juneau,us
# processing request for juneau,us
# city generated: port alfred,za
# processing request for port alfred,za
# city generated: fairbanks,us
# processing request for fairbanks,us
# city generated: mar del plata,ar
# processing request for mar del plata,ar
# city generated: hermanus,za
# processing request for hermanus,za
# city generated: skjervoy,no
# processing request for skjervoy,no
# city generated: faanui,pf
# processing request for faanui,pf
# city generated: almenevo,ru
# processing request for almenevo,ru
# City not found...skipping.
#
# city generated: bethel,us
# processing request for bethel,us
# city generated: blackwater,au
# processing request for blackwater,au
# city generated: sembe,cg
# processing request for sembe,cg
# duplicate city: albany,au
# city generated: motygino,ru
# processing request for motygino,ru
# city generated: kota kinabalu,my
# processing request for kota kinabalu,my
# city generated: new norfolk,au
# processing request for new norfolk,au
# duplicate city: rikitea,pf
# city generated: peterhead,gb
# processing request for peterhead,gb
# city generated: torbay,ca
# processing request for torbay,ca
# city generated: ancud,cl
# processing request for ancud,cl
# city generated: saint george,bm
# processing request for saint george,bm
# city generated: caiaponia,br
# processing request for caiaponia,br
# city generated: oussouye,sn
# processing request for oussouye,sn
# city generated: karratha,au
# processing request for karratha,au
# duplicate city: new norfolk,au
# duplicate city: rikitea,pf
# city generated: bud,no
# processing request for bud,no
# city generated: kashan,ir
# processing request for kashan,ir
# duplicate city: mar del plata,ar
# city generated: suez,eg
# processing request for suez,eg
# city generated: iqaluit,ca
# processing request for iqaluit,ca
# city generated: kanungu,ug
# processing request for kanungu,ug
# city generated: barentsburg,sj
# processing request for barentsburg,sj
# City not found...skipping.
#
# city generated: prince rupert,ca
# processing request for prince rupert,ca
# city generated: samfya,zm
# processing request for samfya,zm
# duplicate city: rikitea,pf
# duplicate city: kapaa,us
# duplicate city: ushuaia,ar
# city generated: taolanaro,mg
# processing request for taolanaro,mg
# City not found...skipping.
#
# city generated: pevek,ru
# processing request for pevek,ru
# city generated: nikolayevka,ru
# processing request for nikolayevka,ru
# city generated: ushtobe,kz
# processing request for ushtobe,kz
# city generated: kieta,pg
# processing request for kieta,pg
# duplicate city: busselton,au
# city generated: srandakan,id
# processing request for srandakan,id
# city generated: georgetown,sh
# processing request for georgetown,sh
# city generated: doha,kw
# processing request for doha,kw
# city generated: atar,mr
# processing request for atar,mr
# city generated: leningradskiy,ru
# processing request for leningradskiy,ru
# city generated: arua,ug
# processing request for arua,ug
# city generated: batemans bay,au
# processing request for batemans bay,au
# city generated: santiago de cuba,cu
# processing request for santiago de cuba,cu
# city generated: port elizabeth,za
# processing request for port elizabeth,za
# duplicate city: ushuaia,ar
# duplicate city: new norfolk,au
# duplicate city: taolanaro,mg
# city generated: fonte boa,br
# processing request for fonte boa,br
# duplicate city: illoqqortoormiut,gl
# city generated: castro,cl
# processing request for castro,cl
# city generated: luwuk,id
# processing request for luwuk,id
# city generated: puerto ayora,ec
# processing request for puerto ayora,ec
# city generated: nador,ma
# processing request for nador,ma
# city generated: mataura,pf
# processing request for mataura,pf
# duplicate city: puerto ayora,ec
# city generated: itupiranga,br
# processing request for itupiranga,br
# city generated: bad ems,de
# processing request for bad ems,de
# city generated: boa vista,br
# processing request for boa vista,br
# duplicate city: new norfolk,au
# city generated: lebu,cl
# processing request for lebu,cl
# city generated: butaritari,ki
# processing request for butaritari,ki
# city generated: lorengau,pg
# processing request for lorengau,pg
# duplicate city: tsihombe,mg
# city generated: santiago del estero,ar
# processing request for santiago del estero,ar
# duplicate city: saint george,bm
# duplicate city: mar del plata,ar
# city generated: plettenberg bay,za
# processing request for plettenberg bay,za
# city generated: chuy,uy
# processing request for chuy,uy
# city generated: vaini,to
# processing request for vaini,to
# duplicate city: jamestown,sh
# duplicate city: puerto ayora,ec
# duplicate city: korla,cn
# city generated: mys shmidta,ru
# processing request for mys shmidta,ru
# City not found...skipping.
#
# duplicate city: ushuaia,ar
# city generated: umm lajj,sa
# processing request for umm lajj,sa
# city generated: morondava,mg
# processing request for morondava,mg
# duplicate city: ushuaia,ar
# city generated: tasiilaq,gl
# processing request for tasiilaq,gl
# duplicate city: rikitea,pf
# duplicate city: rikitea,pf
# city generated: sao miguel do araguaia,br
# processing request for sao miguel do araguaia,br
# city generated: port lincoln,au
# processing request for port lincoln,au
# city generated: manadhoo,mv
# processing request for manadhoo,mv
# city generated: beyneu,kz
# processing request for beyneu,kz
# city generated: deputatskiy,ru
# processing request for deputatskiy,ru
# city generated: hilo,us
# processing request for hilo,us
# city generated: catamarca,ar
# processing request for catamarca,ar
# duplicate city: mataura,pf
# duplicate city: mataura,pf
# duplicate city: port alfred,za
# city generated: pahrump,us
# processing request for pahrump,us
# duplicate city: kodiak,us
# duplicate city: port elizabeth,za
# city generated: acapulco,mx
# processing request for acapulco,mx
# city generated: wladyslawowo,pl
# processing request for wladyslawowo,pl
# city generated: nikolskoye,ru
# processing request for nikolskoye,ru
# duplicate city: vaini,to
# duplicate city: busselton,au
# duplicate city: pevek,ru
# duplicate city: punta arenas,cl
# city generated: abnub,eg
# processing request for abnub,eg
# duplicate city: tasiilaq,gl
# city generated: sur,om
# processing request for sur,om
# duplicate city: rikitea,pf
# city generated: hambantota,lk
# processing request for hambantota,lk
# duplicate city: port hardy,ca
# duplicate city: tuktoyaktuk,ca
# city generated: nampula,mz
# processing request for nampula,mz
# duplicate city: jamestown,sh
# city generated: yellowknife,ca
# processing request for yellowknife,ca
# duplicate city: lebu,cl
# duplicate city: rikitea,pf
# duplicate city: illoqqortoormiut,gl
# city generated: abu zabad,sd
# processing request for abu zabad,sd
# city generated: ulladulla,au
# processing request for ulladulla,au
# city generated: manjacaze,mz
# processing request for manjacaze,mz
# duplicate city: vaini,to
# city generated: bengkulu,id
# processing request for bengkulu,id
# city generated: ambilobe,mg
# processing request for ambilobe,mg
# city generated: bolu,tr
# processing request for bolu,tr
# duplicate city: punta arenas,cl
# duplicate city: tuktoyaktuk,ca
# city generated: amderma,ru
# processing request for amderma,ru
# City not found...skipping.
#
# duplicate city: punta arenas,cl
# duplicate city: illoqqortoormiut,gl
# city generated: winchester,us
# processing request for winchester,us
# city generated: antofagasta,cl
# processing request for antofagasta,cl
# city generated: victoria,sc
# processing request for victoria,sc
# duplicate city: rikitea,pf
# city generated: aviles,es
# processing request for aviles,es
# duplicate city: chuy,uy
# city generated: east london,za
# processing request for east london,za
# city generated: sao joao da barra,br
# processing request for sao joao da barra,br
# city generated: vyartsilya,ru
# processing request for vyartsilya,ru
# duplicate city: puerto ayora,ec
# duplicate city: tsihombe,mg
# city generated: wahran,dz
# processing request for wahran,dz
# City not found...skipping.
#
# duplicate city: new norfolk,au
# duplicate city: rikitea,pf
# duplicate city: hermanus,za
# city generated: katsuura,jp
# processing request for katsuura,jp
# city generated: sangar,ru
# processing request for sangar,ru
# city generated: vila franca do campo,pt
# processing request for vila franca do campo,pt
# city generated: airai,pw
# processing request for airai,pw
# city generated: provideniya,ru
# processing request for provideniya,ru
# city generated: alice springs,au
# processing request for alice springs,au
# city generated: shingu,jp
# processing request for shingu,jp
# duplicate city: amderma,ru
# duplicate city: lebu,cl
# city generated: atuona,pf
# processing request for atuona,pf
# city generated: ngukurr,au
# processing request for ngukurr,au
# City not found...skipping.
#
# duplicate city: tasiilaq,gl
# duplicate city: amderma,ru
# duplicate city: tsihombe,mg
# city generated: coahuayana,mx
# processing request for coahuayana,mx
# duplicate city: rikitea,pf
# duplicate city: yellowknife,ca
# city generated: kununurra,au
# processing request for kununurra,au
# city generated: farafangana,mg
# processing request for farafangana,mg
# city generated: ust-tsilma,ru
# processing request for ust-tsilma,ru
# city generated: les cayes,ht
# processing request for les cayes,ht
# duplicate city: taolanaro,mg
# duplicate city: busselton,au
# duplicate city: barrow,us
# duplicate city: iqaluit,ca
# duplicate city: busselton,au
# duplicate city: jamestown,sh
# duplicate city: atuona,pf
# duplicate city: port alfred,za
# duplicate city: rikitea,pf
# city generated: yar-sale,ru
# processing request for yar-sale,ru
# city generated: ponta do sol,cv
# processing request for ponta do sol,cv
# duplicate city: punta arenas,cl
# duplicate city: hermanus,za
# duplicate city: cape town,za
# city generated: mandalgovi,mn
# processing request for mandalgovi,mn
# city generated: sheridan,us
# processing request for sheridan,us
# duplicate city: albany,au
# city generated: avarua,ck
# processing request for avarua,ck
# city generated: araouane,ml
# processing request for araouane,ml
# city generated: mahebourg,mu
# processing request for mahebourg,mu
# duplicate city: mys shmidta,ru
# city generated: upernavik,gl
# processing request for upernavik,gl
# city generated: hearst,ca
# processing request for hearst,ca
# city generated: agadez,ne
# processing request for agadez,ne
# duplicate city: lebu,cl
# city generated: kerema,pg
# processing request for kerema,pg
# duplicate city: pevek,ru
# city generated: lasa,cn
# processing request for lasa,cn
# city generated: norman wells,ca
# processing request for norman wells,ca
# duplicate city: saldanha,za
# duplicate city: bengkulu,id
# duplicate city: punta arenas,cl
# duplicate city: tsihombe,mg
# duplicate city: jamestown,sh
# city generated: ventspils,lv
# processing request for ventspils,lv
# city generated: kudahuvadhoo,mv
# processing request for kudahuvadhoo,mv
# duplicate city: korla,cn
# city generated: igrim,ru
# processing request for igrim,ru
# city generated: lagoa,pt
# processing request for lagoa,pt
# duplicate city: busselton,au
# duplicate city: atuona,pf
# duplicate city: puerto ayora,ec
# duplicate city: amderma,ru
# duplicate city: taolanaro,mg
# duplicate city: taolanaro,mg
# duplicate city: morondava,mg
# duplicate city: upernavik,gl
# city generated: hobart,au
# processing request for hobart,au
# duplicate city: airai,pw
# duplicate city: saint-philippe,re
# duplicate city: puerto ayora,ec
# city generated: makakilo city,us
# processing request for makakilo city,us
# duplicate city: punta arenas,cl
# city generated: srednekolymsk,ru
# processing request for srednekolymsk,ru
# city generated: zhenjiang,cn
# processing request for zhenjiang,cn
# duplicate city: atuona,pf
# duplicate city: ushuaia,ar
# city generated: rimbey,ca
# processing request for rimbey,ca
# city generated: husavik,is
# processing request for husavik,is
# city generated: dunedin,nz
# processing request for dunedin,nz
# city generated: jinchang,cn
# processing request for jinchang,cn
# city generated: tawang,in
# processing request for tawang,in
# duplicate city: longyearbyen,sj
# city generated: laguna,br
# processing request for laguna,br
# duplicate city: lebu,cl
# duplicate city: castro,cl
# duplicate city: illoqqortoormiut,gl
# duplicate city: punta arenas,cl
# duplicate city: atuona,pf
# city generated: varkkallai,in
# processing request for varkkallai,in
# duplicate city: taolanaro,mg
# city generated: kawalu,id
# processing request for kawalu,id
# duplicate city: punta arenas,cl
# duplicate city: ambilobe,mg
# city generated: lexington,us
# processing request for lexington,us
# duplicate city: saldanha,za
# duplicate city: illoqqortoormiut,gl
# duplicate city: cape town,za
# duplicate city: albany,au
# duplicate city: barrow,us
# city generated: naze,jp
# processing request for naze,jp
# duplicate city: mataura,pf
# duplicate city: busselton,au
# duplicate city: punta arenas,cl
# duplicate city: leningradskiy,ru
# duplicate city: geraldton,au
# city generated: necochea,ar
# processing request for necochea,ar
# duplicate city: upernavik,gl
# duplicate city: nikolskoye,ru
# duplicate city: castro,cl
# duplicate city: georgetown,sh
# duplicate city: hermanus,za
# city generated: bredasdorp,za
# processing request for bredasdorp,za
# duplicate city: rikitea,pf
# duplicate city: port alfred,za
# city generated: qui nhon,vn
# processing request for qui nhon,vn
# duplicate city: atuona,pf
# duplicate city: sao joao da barra,br
# city generated: vaitupu,wf
# processing request for vaitupu,wf
# City not found...skipping.
#
# duplicate city: bredasdorp,za
# city generated: cururupu,br
# processing request for cururupu,br
# duplicate city: ushuaia,ar
# city generated: balingasay,ph
# processing request for balingasay,ph
# duplicate city: rikitea,pf
# duplicate city: vaini,to
# duplicate city: hilo,us
# duplicate city: kapaa,us
# duplicate city: faanui,pf
# city generated: bluff,nz
# processing request for bluff,nz
# duplicate city: kapaa,us
# duplicate city: hermanus,za
# duplicate city: dikson,ru
# city generated: los llanos de aridane,es
# processing request for los llanos de aridane,es
# city generated: portland,au
# processing request for portland,au
# duplicate city: georgetown,sh
# city generated: riverbank,us
# processing request for riverbank,us
# duplicate city: bluff,nz
# city generated: luganville,vu
# processing request for luganville,vu
# duplicate city: butaritari,ki
# duplicate city: chuy,uy
# duplicate city: jamestown,sh
# city generated: ningan,cn
# processing request for ningan,cn
# City not found...skipping.
#
# city generated: west wendover,us
# processing request for west wendover,us
# duplicate city: illoqqortoormiut,gl
# city generated: kavaratti,in
# processing request for kavaratti,in
# duplicate city: rikitea,pf
# city generated: qaanaaq,gl
# processing request for qaanaaq,gl
# duplicate city: ushuaia,ar
# city generated: mongo,td
# processing request for mongo,td
# duplicate city: airai,pw
# duplicate city: mataura,pf
# duplicate city: yellowknife,ca
# city generated: imeni morozova,ru
# processing request for imeni morozova,ru
# duplicate city: airai,pw
# duplicate city: ushuaia,ar
# duplicate city: nikolskoye,ru
# duplicate city: busselton,au
# duplicate city: hobart,au
# city generated: nisia floresta,br
# processing request for nisia floresta,br
# duplicate city: barrow,us
# duplicate city: saint-philippe,re
# duplicate city: rikitea,pf
# city generated: grand centre,ca
# processing request for grand centre,ca
# City not found...skipping.
#
# city generated: conselheiro pena,br
# processing request for conselheiro pena,br
# duplicate city: rikitea,pf
# duplicate city: ulladulla,au
# duplicate city: castro,cl
# city generated: kavieng,pg
# processing request for kavieng,pg
# city generated: palmer,us
# processing request for palmer,us
# duplicate city: hermanus,za
# duplicate city: saskylakh,ru
# city generated: ponta delgada,pt
# processing request for ponta delgada,pt
# city generated: kulachi,pk
# processing request for kulachi,pk
# city generated: thinadhoo,mv
# processing request for thinadhoo,mv
# duplicate city: hilo,us
# city generated: banjar,id
# processing request for banjar,id
# city generated: gilbues,br
# processing request for gilbues,br
# duplicate city: barentsburg,sj
# city generated: ketchikan,us
# processing request for ketchikan,us
# duplicate city: rikitea,pf
# city generated: bathsheba,bb
# processing request for bathsheba,bb
# city generated: bambous virieux,mu
# processing request for bambous virieux,mu
# duplicate city: bethel,us
# city generated: hualmay,pe
# processing request for hualmay,pe
# city generated: masaya,ph
# processing request for masaya,ph
# duplicate city: hermanus,za
# city generated: zadar,hr
# processing request for zadar,hr
# city generated: esperance,au
# processing request for esperance,au
# duplicate city: qaanaaq,gl
# city generated: cidreira,br
# processing request for cidreira,br
# city generated: alofi,nu
# processing request for alofi,nu
# city generated: churapcha,ru
# processing request for churapcha,ru
# duplicate city: kodiak,us
# city generated: nagai,jp
# processing request for nagai,jp
# city generated: ullapool,gb
# processing request for ullapool,gb
# duplicate city: rikitea,pf
# city generated: sinnamary,gf
# processing request for sinnamary,gf
# city generated: lodwar,ke
# processing request for lodwar,ke
# city generated: nome,us
# processing request for nome,us
# city generated: baykit,ru
# processing request for baykit,ru
# duplicate city: saint-philippe,re
# duplicate city: puerto ayora,ec
# duplicate city: punta arenas,cl
# duplicate city: ushuaia,ar
# duplicate city: punta arenas,cl
# city generated: channahon,us
# processing request for channahon,us
# duplicate city: rikitea,pf
# duplicate city: cidreira,br
# city generated: zhanatas,kz
# processing request for zhanatas,kz
# City not found...skipping.
#
# city generated: roebourne,au
# processing request for roebourne,au
# city generated: khatanga,ru
# processing request for khatanga,ru
# duplicate city: bredasdorp,za
# city generated: wilmington,us
# processing request for wilmington,us
# city generated: cuiaba,br
# processing request for cuiaba,br
# city generated: tabukiniberu,ki
# processing request for tabukiniberu,ki
# City not found...skipping.
#
# city generated: serenje,zm
# processing request for serenje,zm
# duplicate city: mataura,pf
# duplicate city: mahebourg,mu
# city generated: kysyl-syr,ru
# processing request for kysyl-syr,ru
# city generated: apollonia,gr
# processing request for apollonia,gr
# city generated: sabang,id
# processing request for sabang,id
# city generated: kapustin yar-1,ru
# processing request for kapustin yar-1,ru
# City not found...skipping.
#
# duplicate city: cape town,za
# city generated: dukat,ru
# processing request for dukat,ru
# duplicate city: bengkulu,id
# city generated: lebedinyy,ru
# processing request for lebedinyy,ru
# city generated: ponta do sol,pt
# processing request for ponta do sol,pt
# duplicate city: rikitea,pf
# duplicate city: saskylakh,ru
# duplicate city: vila franca do campo,pt
# duplicate city: albany,au
# city generated: urumqi,cn
# processing request for urumqi,cn
# duplicate city: ushuaia,ar
# city generated: burnie,au
# processing request for burnie,au
# city generated: hovd,mn
# processing request for hovd,mn
# duplicate city: bethel,us
# duplicate city: saskylakh,ru
# duplicate city: punta arenas,cl
# duplicate city: hilo,us
# duplicate city: yar-sale,ru
# duplicate city: fairbanks,us
# duplicate city: castro,cl
# city generated: moshkovo,ru
# processing request for moshkovo,ru
# city generated: tanda,ci
# processing request for tanda,ci
# duplicate city: cape town,za
# duplicate city: rikitea,pf
# city generated: byron bay,au
# processing request for byron bay,au
# duplicate city: arraial do cabo,br
# duplicate city: busselton,au
# duplicate city: geraldton,au
# city generated: viligili,mv
# processing request for viligili,mv
# City not found...skipping.
#
# duplicate city: rikitea,pf
# duplicate city: arraial do cabo,br
# duplicate city: punta arenas,cl
# duplicate city: bluff,nz
# city generated: chokurdakh,ru
# processing request for chokurdakh,ru
# city generated: luderitz,na
# processing request for luderitz,na
# duplicate city: punta arenas,cl
# city generated: volchikha,ru
# processing request for volchikha,ru
# city generated: mount gambier,au
# processing request for mount gambier,au
# duplicate city: karratha,au
# city generated: nybro,se
# processing request for nybro,se
# duplicate city: necochea,ar
# city generated: carleton place,ca
# processing request for carleton place,ca
# duplicate city: kapaa,us
# duplicate city: albany,au
# duplicate city: illoqqortoormiut,gl
# duplicate city: nikolskoye,ru
# duplicate city: atuona,pf
# duplicate city: hithadhoo,mv
# duplicate city: vaini,to
# city generated: mackay,au
# processing request for mackay,au
# city generated: asau,tv
# processing request for asau,tv
# city generated: hamilton,bm
# processing request for hamilton,bm
# city generated: saint-joseph,re
# processing request for saint-joseph,re
# duplicate city: chuy,uy
# city generated: kruisfontein,za
# processing request for kruisfontein,za
# duplicate city: kavaratti,in
# city generated: ixtapa,mx
# processing request for ixtapa,mx
# duplicate city: tuktoyaktuk,ca
# city generated: ritchie,za
# processing request for ritchie,za
# city generated: coalcoman,mx
# processing request for coalcoman,mx
# City not found...skipping.
#
# duplicate city: dikson,ru
# duplicate city: rikitea,pf
# duplicate city: saldanha,za
# duplicate city: kodiak,us
# duplicate city: rikitea,pf
# city generated: malwan,in
# processing request for malwan,in
# City not found...skipping.
#
# duplicate city: bengkulu,id
# duplicate city: ponta do sol,pt
# city generated: izhma,ru
# processing request for izhma,ru
# duplicate city: hilo,us
# duplicate city: albany,au
# city generated: yulara,au
# processing request for yulara,au
# duplicate city: illoqqortoormiut,gl
# duplicate city: jamestown,sh
# duplicate city: punta arenas,cl
# city generated: pitkyaranta,ru
# processing request for pitkyaranta,ru
# city generated: aswan,eg
# processing request for aswan,eg
# city generated: san andres,co
# processing request for san andres,co
# city generated: beinamar,td
# processing request for beinamar,td
# duplicate city: taolanaro,mg
# city generated: hami,cn
# processing request for hami,cn
# city generated: terrace,ca
# processing request for terrace,ca
# duplicate city: new norfolk,au
# city generated: rabat,ma
# processing request for rabat,ma
# duplicate city: vila franca do campo,pt
# duplicate city: ushuaia,ar
# city generated: kimberley,za
# processing request for kimberley,za
# city generated: skalistyy,ru
# processing request for skalistyy,ru
# City not found...skipping.
#
# city generated: shu,kz
# processing request for shu,kz
# duplicate city: ushuaia,ar
# duplicate city: upernavik,gl
# city generated: dalen,no
# processing request for dalen,no
# city generated: umzimvubu,za
# processing request for umzimvubu,za
# City not found...skipping.
#
# duplicate city: puerto ayora,ec
# duplicate city: mys shmidta,ru
# duplicate city: punta arenas,cl
# duplicate city: severo-kurilsk,ru
# city generated: padang,id
# processing request for padang,id
# duplicate city: hobart,au
# duplicate city: qaanaaq,gl
# city generated: ngunguru,nz
# processing request for ngunguru,nz
# duplicate city: vaini,to
# duplicate city: rikitea,pf
# city generated: port moresby,pg
# processing request for port moresby,pg
# duplicate city: mataura,pf
# city generated: tomohon,id
# processing request for tomohon,id
# duplicate city: ushuaia,ar
# duplicate city: provideniya,ru
# duplicate city: ullapool,gb
# duplicate city: busselton,au
# duplicate city: albany,au
# duplicate city: rikitea,pf
# duplicate city: port elizabeth,za
# city generated: carnot,cf
# processing request for carnot,cf
# city generated: surt,ly
# processing request for surt,ly
# city generated: campeche,mx
# processing request for campeche,mx
# city generated: milingimbi,au
# processing request for milingimbi,au
# City not found...skipping.
#
# duplicate city: airai,pw
# city generated: burns lake,ca
# processing request for burns lake,ca
# duplicate city: cape town,za
# duplicate city: lorengau,pg
# city generated: bolungarvik,is
# processing request for bolungarvik,is
# City not found...skipping.
#
# duplicate city: rikitea,pf
# duplicate city: sinnamary,gf
# duplicate city: longyearbyen,sj
# city generated: kulu,in
# processing request for kulu,in
# duplicate city: taolanaro,mg
# duplicate city: albany,au
# city generated: pa sang,th
# processing request for pa sang,th
# duplicate city: prince rupert,ca
# city generated: hasaki,jp
# processing request for hasaki,jp
# duplicate city: punta arenas,cl
# city generated: san carlos,mx
# processing request for san carlos,mx
# duplicate city: khatanga,ru
# duplicate city: cape town,za
# city generated: kenai,us
# processing request for kenai,us
# duplicate city: rikitea,pf
# city generated: clarence town,bs
# processing request for clarence town,bs
# city generated: belushya guba,ru
# processing request for belushya guba,ru
# City not found...skipping.
#
# duplicate city: vaini,to
# duplicate city: new norfolk,au
# duplicate city: saint-philippe,re
# city generated: fortuna,us
# processing request for fortuna,us
# duplicate city: albany,au
# duplicate city: bredasdorp,za
# duplicate city: hobart,au
# city generated: magadan,ru
# processing request for magadan,ru
# duplicate city: busselton,au
# city generated: mahuta,tz
# processing request for mahuta,tz
# duplicate city: ushuaia,ar
# duplicate city: rikitea,pf
# duplicate city: padang,id
# duplicate city: longyearbyen,sj
# duplicate city: bolungarvik,is
# duplicate city: bredasdorp,za
# duplicate city: hithadhoo,mv
# duplicate city: atar,mr
# city generated: balta,ua
# processing request for balta,ua
# duplicate city: chuy,uy
# city generated: bismarck,us
# processing request for bismarck,us
# city generated: kutum,sd
# processing request for kutum,sd
# city generated: alexandria,eg
# processing request for alexandria,eg
# city generated: yarada,in
# processing request for yarada,in
# city generated: kourou,gf
# processing request for kourou,gf
# duplicate city: yellowknife,ca
# city generated: kishapu,tz
# processing request for kishapu,tz
# city generated: promyshlennyy,ru
# processing request for promyshlennyy,ru
# city generated: lagos,pt
# processing request for lagos,pt
# duplicate city: karratha,au
# city generated: kochi,in
# processing request for kochi,in
# duplicate city: bluff,nz
# duplicate city: kodiak,us
# city generated: roald,no
# processing request for roald,no
# duplicate city: punta arenas,cl
# duplicate city: ushuaia,ar
# duplicate city: atuona,pf
# city generated: vardo,no
# processing request for vardo,no
# city generated: kaitangata,nz
# processing request for kaitangata,nz
# duplicate city: georgetown,sh
# duplicate city: butaritari,ki
# duplicate city: atasu,kz
# city generated: saurimo,ao
# processing request for saurimo,ao
# duplicate city: bluff,nz
# duplicate city: atuona,pf
# duplicate city: jamestown,sh
# duplicate city: avarua,ck
# duplicate city: saint-philippe,re
# city generated: berlevag,no
# processing request for berlevag,no
# duplicate city: abu zabad,sd
# duplicate city: arraial do cabo,br
# duplicate city: vaini,to
# duplicate city: punta arenas,cl
# duplicate city: vaini,to
# duplicate city: cape town,za
# duplicate city: kapaa,us
# duplicate city: castro,cl
# duplicate city: provideniya,ru
# duplicate city: rikitea,pf
# city generated: yumen,cn
# processing request for yumen,cn
# duplicate city: vila franca do campo,pt
# duplicate city: ushuaia,ar
# city generated: bull savanna,jm
# processing request for bull savanna,jm
# city generated: puerto narino,co
# processing request for puerto narino,co
# duplicate city: jamestown,sh
# duplicate city: taolanaro,mg
# duplicate city: busselton,au
# duplicate city: arraial do cabo,br
# city generated: carnarvon,au
# processing request for carnarvon,au
# duplicate city: rikitea,pf
# city generated: evanston,us
# processing request for evanston,us
# duplicate city: husavik,is
# duplicate city: mataura,pf
# duplicate city: belushya guba,ru
# city generated: nemuro,jp
# processing request for nemuro,jp
# duplicate city: atuona,pf
# city generated: lubao,cd
# processing request for lubao,cd
# duplicate city: hovd,mn
# city generated: boda,cf
# processing request for boda,cf
# city generated: yerkoy,tr
# processing request for yerkoy,tr
# city generated: mbigou,ga
# processing request for mbigou,ga
# duplicate city: mataura,pf
# city generated: biltine,td
# processing request for biltine,td
# duplicate city: punta arenas,cl
# city generated: adelaide,au
# processing request for adelaide,au
# city generated: vestmannaeyjar,is
# processing request for vestmannaeyjar,is
# duplicate city: avarua,ck
# city generated: macaboboni,ph
# processing request for macaboboni,ph
# City not found...skipping.
#
# city generated: hellvik,no
# processing request for hellvik,no
# duplicate city: khatanga,ru
# city generated: lompoc,us
# processing request for lompoc,us
# city generated: bilma,ne
# processing request for bilma,ne
# duplicate city: ushuaia,ar
# duplicate city: saleaula,ws
# duplicate city: arraial do cabo,br
# city generated: cheuskiny,ru
# processing request for cheuskiny,ru
# City not found...skipping.
#
# city generated: port augusta,au
# processing request for port augusta,au
# duplicate city: saskylakh,ru
# duplicate city: ushuaia,ar
# city generated: palabuhanratu,id
# processing request for palabuhanratu,id
# City not found...skipping.
#
# duplicate city: yellowknife,ca
# duplicate city: avarua,ck
# duplicate city: saldanha,za
# city generated: ocos,gt
# processing request for ocos,gt
# duplicate city: busselton,au
# duplicate city: dikson,ru
# duplicate city: kapaa,us
# duplicate city: busselton,au
# city generated: pojuca,br
# processing request for pojuca,br
# duplicate city: norman wells,ca
# city generated: khor,qa
# processing request for khor,qa
# city generated: yerbogachen,ru
# processing request for yerbogachen,ru
# duplicate city: kutum,sd
# duplicate city: amderma,ru
# city generated: okhotsk,ru
# processing request for okhotsk,ru
# duplicate city: kodiak,us
# city generated: pangnirtung,ca
# processing request for pangnirtung,ca
# duplicate city: geraldton,au
# city generated: nacala,mz
# processing request for nacala,mz
# duplicate city: busselton,au
# city generated: avera,pf
# processing request for avera,pf
# duplicate city: albany,au
# duplicate city: san quintin,mx
# duplicate city: carnarvon,au
# duplicate city: busselton,au
# duplicate city: hasaki,jp
# city generated: sentyabrskiy,ru
# processing request for sentyabrskiy,ru
# City not found...skipping.
#
# city generated: dzhebariki-khaya,ru
# processing request for dzhebariki-khaya,ru
# duplicate city: thompson,ca
# duplicate city: albany,au
# city generated: tilichiki,ru
# processing request for tilichiki,ru
# duplicate city: ushuaia,ar
# duplicate city: berlevag,no
# duplicate city: saint george,bm
# duplicate city: zhanatas,kz
# duplicate city: khatanga,ru
# city generated: wana,pk
# processing request for wana,pk
# duplicate city: atuona,pf
# city generated: santa rosa,ar
# processing request for santa rosa,ar
# city generated: kaeo,nz
# processing request for kaeo,nz
# duplicate city: lompoc,us
# duplicate city: asau,tv
# duplicate city: mataura,pf
# duplicate city: illoqqortoormiut,gl
# city generated: chicama,pe
# processing request for chicama,pe
# city generated: santa barbara,mx
# processing request for santa barbara,mx
# duplicate city: qaanaaq,gl
# city generated: nizhneyansk,ru
# processing request for nizhneyansk,ru
# City not found...skipping.
#
# city generated: birzai,lt
# processing request for birzai,lt
# city generated: manggar,id
# processing request for manggar,id
# duplicate city: butaritari,ki
# city generated: huambo,ao
# processing request for huambo,ao
# city generated: alekseyevskoye,ru
# processing request for alekseyevskoye,ru
# duplicate city: bethel,us
# city generated: flums,ch
# processing request for flums,ch
# duplicate city: ushuaia,ar
# duplicate city: atuona,pf
# duplicate city: mataura,pf
# duplicate city: ancud,cl
# duplicate city: tuktoyaktuk,ca
# city generated: marawi,sd
# processing request for marawi,sd
# city generated: salinas,ec
# processing request for salinas,ec
# city generated: ugoofaaru,mv
# processing request for ugoofaaru,mv
# city generated: tiksi,ru
# processing request for tiksi,ru
# duplicate city: esperance,au
# duplicate city: castro,cl
# city generated: talcahuano,cl
# processing request for talcahuano,cl
# city generated: paradwip,in
# processing request for paradwip,in
# City not found...skipping.
#
# city generated: tuggurt,dz
# processing request for tuggurt,dz
# City not found...skipping.
#
# duplicate city: norman wells,ca
# city generated: champerico,gt
# processing request for champerico,gt
# city generated: vila,vu
# processing request for vila,vu
# duplicate city: chuy,uy
# duplicate city: puerto ayora,ec
# duplicate city: ushuaia,ar
# city generated: longview,us
# processing request for longview,us
# city generated: alamos,mx
# processing request for alamos,mx
# duplicate city: qaanaaq,gl
# city generated: abu dhabi,ae
# processing request for abu dhabi,ae
# duplicate city: barrow,us
# duplicate city: hermanus,za
# city generated: sussex,ca
# processing request for sussex,ca
# duplicate city: ushuaia,ar
# city generated: dauriya,ru
# processing request for dauriya,ru
# duplicate city: busselton,au
# duplicate city: barentsburg,sj
# duplicate city: busselton,au
# city generated: soyo,ao
# processing request for soyo,ao
# city generated: akdepe,tm
# processing request for akdepe,tm
# duplicate city: hilo,us
# city generated: shache,cn
# processing request for shache,cn
# duplicate city: ushuaia,ar
# duplicate city: port alfred,za
# city generated: udachnyy,ru
# processing request for udachnyy,ru
# city generated: lavrentiya,ru
# processing request for lavrentiya,ru
# duplicate city: hithadhoo,mv
# city generated: egvekinot,ru
# processing request for egvekinot,ru
# city generated: pombia,gr
# processing request for pombia,gr
# duplicate city: fortuna,us
# duplicate city: atuona,pf
# duplicate city: ushuaia,ar
# duplicate city: mahebourg,mu
# city generated: narsaq,gl
# processing request for narsaq,gl
# city generated: savonlinna,fi
# processing request for savonlinna,fi
# duplicate city: husavik,is
# duplicate city: grand river south east,mu
# duplicate city: ushuaia,ar
# city generated: troitskoye,ru
# processing request for troitskoye,ru
# city generated: kirensk,ru
# processing request for kirensk,ru
# duplicate city: jamestown,sh
# city generated: zhangye,cn
# processing request for zhangye,cn
# duplicate city: saint george,bm
# duplicate city: hobart,au
# city generated: wagar,sd
# processing request for wagar,sd
# duplicate city: barrow,us
# duplicate city: jamestown,sh
# city generated: topeka,us
# processing request for topeka,us
# city generated: maniitsoq,gl
# processing request for maniitsoq,gl
# duplicate city: jamestown,sh
# city generated: grand gaube,mu
# processing request for grand gaube,mu
# city generated: gobabis,na
# processing request for gobabis,na
# duplicate city: thompson,ca
# duplicate city: nome,us
# city generated: cabo san lucas,mx
# processing request for cabo san lucas,mx
# duplicate city: belushya guba,ru
# duplicate city: jamestown,sh
# duplicate city: hithadhoo,mv
# city generated: buala,sb
# processing request for buala,sb
# duplicate city: punta arenas,cl
# duplicate city: ushuaia,ar
# duplicate city: busselton,au
# duplicate city: ngukurr,au
# city generated: sikasso,ml
# processing request for sikasso,ml
# duplicate city: port elizabeth,za
# duplicate city: port alfred,za
# duplicate city: barentsburg,sj
# duplicate city: illoqqortoormiut,gl
# duplicate city: rikitea,pf
# duplicate city: carnarvon,au
# duplicate city: ushuaia,ar
# city generated: piacabucu,br
# processing request for piacabucu,br
# duplicate city: barentsburg,sj
# city generated: pimentel,pe
# processing request for pimentel,pe
# duplicate city: punta arenas,cl
# duplicate city: mar del plata,ar
# duplicate city: hamilton,bm
# duplicate city: jamestown,sh
# duplicate city: hobart,au
# city generated: ahipara,nz
# processing request for ahipara,nz
# duplicate city: atuona,pf
# duplicate city: hermanus,za
# city generated: san carlos de bariloche,ar
# processing request for san carlos de bariloche,ar
# duplicate city: belushya guba,ru
# duplicate city: kapaa,us
# duplicate city: lebu,cl
# duplicate city: port elizabeth,za
# city generated: nyagan,ru
# processing request for nyagan,ru
# city generated: alta floresta,br
# processing request for alta floresta,br
# city generated: inderborskiy,kz
# processing request for inderborskiy,kz
# City not found...skipping.
#
# duplicate city: hithadhoo,mv
# city generated: bazaliya,ua
# processing request for bazaliya,ua
# city generated: zlitan,ly
# processing request for zlitan,ly
# duplicate city: hobart,au
# duplicate city: maniitsoq,gl
# duplicate city: longyearbyen,sj
# duplicate city: barentsburg,sj
# city generated: anjar,in
# processing request for anjar,in
# city generated: te anau,nz
# processing request for te anau,nz
# duplicate city: cape town,za
# city generated: sataua,ws
# processing request for sataua,ws
# City not found...skipping.
#
# duplicate city: doha,kw
# duplicate city: albany,au
# city generated: gat,ly
# processing request for gat,ly
# city generated: ludvika,se
# processing request for ludvika,se
# city generated: toora-khem,ru
# processing request for toora-khem,ru
# duplicate city: puerto ayora,ec
# duplicate city: east london,za
# duplicate city: hilo,us
# city generated: prokudskoye,ru
# processing request for prokudskoye,ru
# city generated: bayanday,ru
# processing request for bayanday,ru
# city generated: bubaque,gw
# processing request for bubaque,gw
# duplicate city: upernavik,gl
# duplicate city: saskylakh,ru
# duplicate city: port alfred,za
# duplicate city: kaitangata,nz
# city generated: praia da vitoria,pt
# processing request for praia da vitoria,pt
# city generated: sao filipe,cv
# processing request for sao filipe,cv
# city generated: lusambo,cd
# processing request for lusambo,cd
# duplicate city: ushuaia,ar
# duplicate city: ushuaia,ar
# duplicate city: tasiilaq,gl
# duplicate city: portland,au
# duplicate city: rikitea,pf
# city generated: kuching,my
# processing request for kuching,my
# city generated: wynyard,ca
# processing request for wynyard,ca
# duplicate city: upernavik,gl
# city generated: honningsvag,no
# processing request for honningsvag,no
# duplicate city: ushuaia,ar
# duplicate city: ponta do sol,pt
# city generated: amontada,br
# processing request for amontada,br
# duplicate city: narsaq,gl
# duplicate city: atuona,pf
# duplicate city: jamestown,sh
# duplicate city: taolanaro,mg
# duplicate city: ushuaia,ar
# duplicate city: los llanos de aridane,es
# duplicate city: ushuaia,ar
# city generated: vostok,ru
# processing request for vostok,ru
# duplicate city: bredasdorp,za
# city generated: westport,nz
# processing request for westport,nz
# city generated: louisbourg,ca
# processing request for louisbourg,ca
# City not found...skipping.
#
# duplicate city: hasaki,jp
# city generated: romilly-sur-seine,fr
# processing request for romilly-sur-seine,fr
# duplicate city: rikitea,pf
# city generated: comodoro rivadavia,ar
# processing request for comodoro rivadavia,ar
# duplicate city: mar del plata,ar
# duplicate city: leningradskiy,ru
# city generated: tessalit,ml
# processing request for tessalit,ml
# duplicate city: ponta delgada,pt
# duplicate city: thompson,ca
# duplicate city: belushya guba,ru
# city generated: homer,us
# processing request for homer,us
# city generated: marienburg,sr
# processing request for marienburg,sr
# city generated: lapua,fi
# processing request for lapua,fi
# city generated: ambon,id
# processing request for ambon,id
# city generated: dali,cn
# processing request for dali,cn
# duplicate city: deputatskiy,ru
# city generated: hobyo,so
# processing request for hobyo,so
# duplicate city: bredasdorp,za
# duplicate city: yar-sale,ru
# duplicate city: bredasdorp,za
# city generated: buraydah,sa
# processing request for buraydah,sa
# city generated: nanortalik,gl
# processing request for nanortalik,gl
# duplicate city: arraial do cabo,br
# duplicate city: punta arenas,cl
# duplicate city: east london,za
# duplicate city: bethel,us
# duplicate city: yellowknife,ca
# duplicate city: bethel,us
# city generated: calvinia,za
# processing request for calvinia,za
# duplicate city: wladyslawowo,pl
# duplicate city: hermanus,za
# duplicate city: ushuaia,ar
# city generated: rabaul,pg
# processing request for rabaul,pg
# duplicate city: busselton,au
# duplicate city: bredasdorp,za
# city generated: pombas,cv
# processing request for pombas,cv
# duplicate city: jamestown,sh
# duplicate city: rikitea,pf
# duplicate city: ribeira grande,pt
# city generated: henties bay,na
# processing request for henties bay,na
# city generated: amudat,ug
# processing request for amudat,ug
# duplicate city: vostok,ru
# city generated: jardim,br
# processing request for jardim,br
# city generated: pacific grove,us
# processing request for pacific grove,us
# duplicate city: tiksi,ru
# city generated: san cristobal,ec
# processing request for san cristobal,ec
# duplicate city: albany,au
# city generated: rehoboth,na
# processing request for rehoboth,na
# city generated: waingapu,id
# processing request for waingapu,id
# duplicate city: cidreira,br
# city generated: linshu,cn
# processing request for linshu,cn
# City not found...skipping.
#
# city generated: nekhayevskiy,ru
# processing request for nekhayevskiy,ru
# duplicate city: atuona,pf
# duplicate city: punta arenas,cl
# duplicate city: kodiak,us
# duplicate city: butaritari,ki
# city generated: inhambane,mz
# processing request for inhambane,mz
# city generated: urengoy,ru
# processing request for urengoy,ru
# city generated: qasigiannguit,gl
# processing request for qasigiannguit,gl
# city generated: gazojak,tm
# processing request for gazojak,tm
# city generated: napier,nz
# processing request for napier,nz
# duplicate city: port lincoln,au
# city generated: marcona,pe
# processing request for marcona,pe
# City not found...skipping.
#
# duplicate city: zhangye,cn
# city generated: kalmunai,lk
# processing request for kalmunai,lk
# duplicate city: egvekinot,ru
# duplicate city: qaanaaq,gl
# duplicate city: kapaa,us
# city generated: saint-louis,re
# processing request for saint-louis,re
# duplicate city: alice springs,au
# duplicate city: pevek,ru
# city generated: caravelas,br
# processing request for caravelas,br
# duplicate city: atuona,pf
# duplicate city: ambilobe,mg
# city generated: shimoda,jp
# processing request for shimoda,jp
# duplicate city: qaanaaq,gl
# duplicate city: ushuaia,ar
# city generated: gorontalo,id
# processing request for gorontalo,id
# duplicate city: rikitea,pf
# duplicate city: rikitea,pf
# duplicate city: qaanaaq,gl
# city generated: ormara,pk
# processing request for ormara,pk
# city generated: amazar,ru
# processing request for amazar,ru
# city generated: hihifo,to
# processing request for hihifo,to
# City not found...skipping.
#
# duplicate city: yellowknife,ca
# city generated: samarai,pg
# processing request for samarai,pg
# duplicate city: busselton,au
# city generated: itarema,br
# processing request for itarema,br
# duplicate city: hilo,us
# city generated: dingle,ie
# processing request for dingle,ie
# city generated: puerto maldonado,pe
# processing request for puerto maldonado,pe
# city generated: saint-augustin,ca
# processing request for saint-augustin,ca
# duplicate city: barrow,us
# duplicate city: arraial do cabo,br
# city generated: whakatane,nz
# processing request for whakatane,nz
# duplicate city: new norfolk,au
# duplicate city: ushuaia,ar
# duplicate city: bredasdorp,za
# duplicate city: faanui,pf
# city generated: rajgurunagar,in
# processing request for rajgurunagar,in
# city generated: cabedelo,br
# processing request for cabedelo,br
# city generated: walvis bay,na
# processing request for walvis bay,na
# duplicate city: castro,cl
# city generated: riverton,nz
# processing request for riverton,nz
# duplicate city: port elizabeth,za
# duplicate city: castro,cl
# city generated: riyadh,sa
# processing request for riyadh,sa
# duplicate city: rikitea,pf
# duplicate city: henties bay,na
# duplicate city: punta arenas,cl
# city generated: cherskiy,ru
# processing request for cherskiy,ru
# city generated: muros,es
# processing request for muros,es
# duplicate city: busselton,au
# city generated: itanagar,in
# processing request for itanagar,in
# duplicate city: nizhneyansk,ru
# duplicate city: punta arenas,cl
# city generated: lithgow,au
# processing request for lithgow,au
# city generated: talnakh,ru
# processing request for talnakh,ru
# duplicate city: ambilobe,mg
# duplicate city: bluff,nz
# city generated: cayenne,gf
# processing request for cayenne,gf
# duplicate city: bambous virieux,mu
# duplicate city: georgetown,sh
# duplicate city: saint-philippe,re
# city generated: noyabrsk,ru
# processing request for noyabrsk,ru
# duplicate city: grand river south east,mu
# city generated: matara,lk
# processing request for matara,lk
# city generated: contamana,pe
# processing request for contamana,pe
# city generated: dryden,ca
# processing request for dryden,ca
# duplicate city: kapaa,us
# city generated: mehamn,no
# processing request for mehamn,no
# city generated: safwah,sa
# processing request for safwah,sa
# City not found...skipping.
#
# duplicate city: albany,au
# duplicate city: acapulco,mx
# duplicate city: hithadhoo,mv
# duplicate city: port alfred,za
# duplicate city: hobart,au
# duplicate city: dikson,ru
# city generated: khao yoi,th
# processing request for khao yoi,th
# duplicate city: busselton,au
# city generated: balabac,ph
# processing request for balabac,ph
# duplicate city: mahebourg,mu
# duplicate city: hobart,au
# duplicate city: bredasdorp,za
# city generated: meulaboh,id
# processing request for meulaboh,id
# city generated: nalobikha,ru
# processing request for nalobikha,ru
# city generated: ternate,id
# processing request for ternate,id
# duplicate city: bluff,nz
# duplicate city: mataura,pf
# city generated: nagorsk,ru
# processing request for nagorsk,ru
# duplicate city: barentsburg,sj
# duplicate city: atuona,pf
# duplicate city: torbay,ca
# duplicate city: yellowknife,ca
# city generated: ilulissat,gl
# processing request for ilulissat,gl
# duplicate city: saint-philippe,re
# duplicate city: puerto ayora,ec
# duplicate city: amderma,ru
# city generated: evenskjaer,no
# processing request for evenskjaer,no
# City not found...skipping.
#
# duplicate city: narsaq,gl
# duplicate city: cabo san lucas,mx
# duplicate city: rikitea,pf
# duplicate city: kapaa,us
# duplicate city: saskylakh,ru
# duplicate city: rikitea,pf
# city generated: kawana waters,au
# processing request for kawana waters,au
# City not found...skipping.
#
# city generated: sedelnikovo,ru
# processing request for sedelnikovo,ru
# City not found...skipping.
#
# city generated: high rock,bs
# processing request for high rock,bs
# duplicate city: mackay,au
# duplicate city: castro,cl
# city generated: shitanjing,cn
# processing request for shitanjing,cn
# city generated: pisco,pe
# processing request for pisco,pe
# duplicate city: kapaa,us
# duplicate city: ushuaia,ar
# duplicate city: illoqqortoormiut,gl
# city generated: nantucket,us
# processing request for nantucket,us
# duplicate city: rikitea,pf
# city generated: colac,au
# processing request for colac,au
# duplicate city: punta arenas,cl
# duplicate city: dikson,ru
# city generated: ruatoria,nz
# processing request for ruatoria,nz
# City not found...skipping.
#
# duplicate city: busselton,au
# city generated: ust-nera,ru
# processing request for ust-nera,ru
# city generated: abbeyfeale,ie
# processing request for abbeyfeale,ie
# duplicate city: ushuaia,ar
# duplicate city: bambous virieux,mu
# duplicate city: illoqqortoormiut,gl
# duplicate city: cape town,za
# city generated: san ignacio,bo
# processing request for san ignacio,bo
# duplicate city: dikson,ru
# duplicate city: barrow,us
# duplicate city: qaanaaq,gl
# city generated: mbacke,sn
# processing request for mbacke,sn
# City not found...skipping.
#
# city generated: kedrovyy,ru
# processing request for kedrovyy,ru
# duplicate city: sao filipe,cv
# duplicate city: taolanaro,mg
# city generated: port keats,au
# processing request for port keats,au
# duplicate city: khatanga,ru
# duplicate city: rikitea,pf
# city generated: sorvag,fo
# processing request for sorvag,fo
# City not found...skipping.
#
# duplicate city: punta arenas,cl
# duplicate city: barrow,us
# duplicate city: aklavik,ca
# duplicate city: airai,pw
# city generated: grindavik,is
# processing request for grindavik,is
# duplicate city: new norfolk,au
# duplicate city: grand gaube,mu
# duplicate city: barentsburg,sj
# city generated: verkh-usugli,ru
# processing request for verkh-usugli,ru
# duplicate city: tiksi,ru
# city generated: aksu,cn
# processing request for aksu,cn
# duplicate city: bilma,ne
# duplicate city: san quintin,mx
# duplicate city: luderitz,na
# city generated: roswell,us
# processing request for roswell,us
# duplicate city: cherskiy,ru
# duplicate city: cape town,za
# duplicate city: cape town,za
# duplicate city: hermanus,za
# city generated: kahului,us
# processing request for kahului,us
# city generated: lososina,ru
# processing request for lososina,ru
# duplicate city: kodiak,us
# duplicate city: tuktoyaktuk,ca
# duplicate city: ngunguru,nz
# city generated: koslan,ru
# processing request for koslan,ru
# city generated: rudnogorsk,ru
# processing request for rudnogorsk,ru
# duplicate city: pevek,ru
# city generated: vila velha,br
# processing request for vila velha,br
# city generated: navolato,mx
# processing request for navolato,mx
# duplicate city: chokurdakh,ru
# duplicate city: port augusta,au
# duplicate city: ushuaia,ar
# duplicate city: saint-philippe,re
# duplicate city: ambilobe,mg
# duplicate city: hobart,au
# city generated: dauphin,ca
# processing request for dauphin,ca
# duplicate city: ancud,cl
# city generated: cape elizabeth,us
# processing request for cape elizabeth,us
# City not found...skipping.
#
# duplicate city: butaritari,ki
# duplicate city: ponta do sol,cv
# duplicate city: airai,pw
# city generated: mlonggo,id
# processing request for mlonggo,id
# duplicate city: butaritari,ki
# city generated: jumla,np
# processing request for jumla,np
# city generated: inuvik,ca
# processing request for inuvik,ca
# duplicate city: kapaa,us
# duplicate city: butaritari,ki
# city generated: clifton,us
# processing request for clifton,us
# city generated: clyde river,ca
# processing request for clyde river,ca
# city generated: salalah,om
# processing request for salalah,om
# city generated: itoman,jp
# processing request for itoman,jp
# duplicate city: narsaq,gl
# duplicate city: ushuaia,ar
# city generated: sabha,ly
# processing request for sabha,ly
# city generated: visby,se
# processing request for visby,se
# city generated: klaksvik,fo
# processing request for klaksvik,fo
# city generated: pryazha,ru
# processing request for pryazha,ru
# duplicate city: longyearbyen,sj
# city generated: lima,pe
# processing request for lima,pe
# duplicate city: umzimvubu,za
# duplicate city: dikson,ru
# duplicate city: port alfred,za
# city generated: codrington,ag
# processing request for codrington,ag
# duplicate city: nantucket,us
# duplicate city: dikson,ru
# duplicate city: saint-philippe,re
# city generated: meyungs,pw
# processing request for meyungs,pw
# City not found...skipping.
#
# duplicate city: vaini,to
# duplicate city: mataura,pf
# city generated: bandarbeyla,so
# processing request for bandarbeyla,so
# city generated: isangel,vu
# processing request for isangel,vu
# duplicate city: airai,pw
# city generated: kupang,id
# processing request for kupang,id
# city generated: cockburn town,tc
# processing request for cockburn town,tc
# duplicate city: thinadhoo,mv
# duplicate city: atuona,pf
# duplicate city: avera,pf
# city generated: provins,fr
# processing request for provins,fr
# duplicate city: nikolskoye,ru
# duplicate city: taolanaro,mg
# duplicate city: rikitea,pf
# duplicate city: vardo,no
# duplicate city: khatanga,ru
# duplicate city: pangnirtung,ca
# duplicate city: marienburg,sr
# duplicate city: vardo,no
# duplicate city: tessalit,ml
# duplicate city: rikitea,pf
# city generated: yabelo,et
# processing request for yabelo,et
# duplicate city: faanui,pf
# city generated: fort nelson,ca
# processing request for fort nelson,ca
# duplicate city: qaanaaq,gl
# city generated: carupano,ve
# processing request for carupano,ve
# city generated: vorobyevka,ru
# processing request for vorobyevka,ru
# duplicate city: kapaa,us
# duplicate city: atuona,pf
# city generated: rathkeale,ie
# processing request for rathkeale,ie
# city generated: souris,ca
# processing request for souris,ca
# city generated: rocha,uy
# processing request for rocha,uy
# duplicate city: rikitea,pf
# duplicate city: busselton,au
# duplicate city: mar del plata,ar
# duplicate city: taolanaro,mg
# duplicate city: vaini,to
# city generated: cherdyn,ru
# processing request for cherdyn,ru
# city generated: le creusot,fr
# processing request for le creusot,fr
# city generated: nouakchott,mr
# processing request for nouakchott,mr
# duplicate city: kapaa,us
# duplicate city: tuktoyaktuk,ca
# city generated: jalu,ly
# processing request for jalu,ly
# duplicate city: tsihombe,mg
# duplicate city: cape town,za
# duplicate city: vila,vu
# city generated: kihei,us
# processing request for kihei,us
# city generated: sahrak,af
# processing request for sahrak,af
# City not found...skipping.
#
# city generated: plouzane,fr
# processing request for plouzane,fr
# ****************************************
# End of Data Retrieval

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print(len(cities_name))
# Out:
# 500

# %%
print(len(duplicate_cities))
# Out:
# 644

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Zip all lists together into tuples
city_ID = list(range(len(cities_name)))
weather_zip = zip(city_ID, cities_name, countries, dates, humidities, latitudes, longititudes, max_temps, clouds, wind_speeds)

# # # save the output file path "ISO-8859-1"
output_file = os.path.join("cities.csv")
 
# #  open the output file, create a header row, and then write the zipped object to the csv
with open(output_file, "w", encoding='utf-8') as datafile:
    writer = csv.writer(datafile)
    writer.writerow(["City_ID", "City", "Country","Date", "Humidity", "Lat", "Long", "Max Temp(F)","Cloudiness", "Wind Speed"])
    writer.writerows(weather_zip)

# %%
file = os.path.join("cities.csv")
weather_df = pd.read_csv(file, encoding= 'utf-8')

weather_df.head(30)
# Out:
#     City_ID             City Country        Date  Humidity    Lat    Long  \
# 0         0         Thompson      CA  1600382570        36  55.74  -97.86
# 1         1        Saskylakh      RU  1600382571        79  71.92  114.08
# 2         2     Jacareacanga      BR  1600382571        41  -6.22  -57.75
# 3         3          Ushuaia      AR  1600382437        86 -54.80  -68.30
# 4         4        Galveston      US  1600382571        62  29.37  -94.97
# 5         5          Rikitea      PF  1600382571        79 -23.12 -134.97
# 6         6              Edd      ER  1600382572        67  13.93   41.69
# 7         7     Punta Arenas      CL  1600382288        69 -53.15  -70.92
# 8         8           Albany      US  1600382493        80  42.60  -73.97
# 9         9  Arraial do Cabo      BR  1600382572        83 -22.97  -42.03
# 10       10        Hithadhoo      MV  1600382572        81  -0.60   73.08
# 11       11        Busselton      AU  1600382311        57 -33.65  115.33
# 12       12           Dikson      RU  1600382573        95  73.51   80.55
# 13       13           Bajmok      RS  1600382573        58  45.97   19.42
# 14       14            Atasū      KZ  1600382573        84  48.68   71.64
# 15       15            Kapaa      US  1600382573        58  22.08 -159.32
# 16       16        Kyzyl-Suu      KG  1600382574        78  42.34   78.00
# 17       17         Saldanha      ZA  1600382574        81 -33.01   17.94
# 18       18      San Quintín      MX  1600382574        29  30.48 -115.95
# 19       19        Geraldton      AU  1600382574        75 -28.77  114.60
# 20       20           Barrow      US  1600382574        87  71.29 -156.79
# 21       21        Cape Town      ZA  1600382342        93 -33.93   18.42
# 22       22           Bantry      IE  1600382361        87  51.68   -9.45
# 23       23   Ribeira Grande      PT  1600382575        86  38.52  -28.70
# 24       24        Jamestown      US  1600382575        72  42.10  -79.24
# 25       25      Tuktoyaktuk      CA  1600382576        81  69.45 -133.04
# 26       26           Touros      BR  1600382576        78  -5.20  -35.46
# 27       27        Evinayong      GQ  1600382576        98   1.44   10.55
# 28       28   Saint-Philippe      RE  1600382576        63 -21.36   55.77
# 29       29           Harper      LR  1600382576        87   4.38   -7.72
#
#     Max Temp(F)  Cloudiness  Wind Speed
# 0         48.20          40       10.29
# 1         46.62           0        8.75
# 2         87.80          65        2.51
# 3         33.80          75       26.40
# 4         88.00          20        4.70
# 5         72.12          86       21.61
# 6         88.99          66        7.27
# 7         37.40          40       34.45
# 8         62.01         100        7.02
# 9         73.40           0       13.87
# 10        82.13          81       11.32
# 11        46.99           0        9.60
# 12        44.20         100        8.50
# 13        64.09          94       17.11
# 14        48.92          75       13.35
# 15        87.80          40       11.41
# 16        48.31          99        5.17
# 17        51.80           0        2.24
# 18        87.13          10       16.69
# 19        46.40           0        6.93
# 20        46.40          90        9.17
# 21        52.00          18        2.24
# 22        57.20           3       14.99
# 23        70.74         100       17.38
# 24        63.00          20        5.82
# 25        48.20          75        3.36
# 26        77.00          20        9.17
# 27        68.09          85        2.04
# 28        66.00          48        6.93
# 29        74.97         100       10.54

# %%
weather_df.describe()
# Out:
#           City_ID          Date    Humidity         Lat       Long  \
# count  500.000000  5.000000e+02  500.000000  500.000000  500.00000
# mean   249.500000  1.600383e+09   70.398000   20.569960   19.28892
# std    144.481833  7.086454e+01   20.891062   33.830411   90.31765
# min      0.000000  1.600382e+09    3.000000  -54.800000 -179.17000
# 25%    124.750000  1.600383e+09   62.000000   -7.342500  -56.50250
# 50%    249.500000  1.600383e+09   76.000000   24.280000   24.69500
# 75%    374.250000  1.600383e+09   86.000000   50.030000   96.19000
# max    499.000000  1.600383e+09  100.000000   78.220000  178.42000
#
#        Max Temp(F)  Cloudiness  Wind Speed
# count    500.00000  500.000000  500.000000
# mean      65.46606   47.800000    8.144220
# std       15.74989   38.711978    5.712129
# min       19.36000    0.000000    0.400000
# 25%       51.78250    4.000000    3.620000
# 50%       67.91000   42.500000    6.930000
# 75%       78.08250   89.250000   11.410000
# max      100.99000  100.000000   34.450000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_city_data = weather_df[weather_df["Humidity"] <= 100]
clean_city_data = clean_city_data.reset_index(drop=True)
clean_city_data.describe()
# Out:
#           City_ID          Date    Humidity         Lat       Long  \
# count  500.000000  5.000000e+02  500.000000  500.000000  500.00000
# mean   249.500000  1.600383e+09   70.398000   20.569960   19.28892
# std    144.481833  7.086454e+01   20.891062   33.830411   90.31765
# min      0.000000  1.600382e+09    3.000000  -54.800000 -179.17000
# 25%    124.750000  1.600383e+09   62.000000   -7.342500  -56.50250
# 50%    249.500000  1.600383e+09   76.000000   24.280000   24.69500
# 75%    374.250000  1.600383e+09   86.000000   50.030000   96.19000
# max    499.000000  1.600383e+09  100.000000   78.220000  178.42000
#
#        Max Temp(F)  Cloudiness  Wind Speed
# count    500.00000  500.000000  500.000000
# mean      65.46606   47.800000    8.144220
# std       15.74989   38.711978    5.712129
# min       19.36000    0.000000    0.400000
# 25%       51.78250    4.000000    3.620000
# 50%       67.91000   42.500000    6.930000
# 75%       78.08250   89.250000   11.410000
# max      100.99000  100.000000   34.450000

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
clean_city_data.plot.scatter(x='Lat',
                      y='Max Temp(F)',
                      c='RoyalBlue', marker="o", edgecolors="black", s = 40,  alpha=0.8, grid = True)

plt.title('City Latitude vs. Maximum Temperature')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature(F)')
# Out:
# Text(0, 0.5, 'Maximum Temperature(F)')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
clean_city_data.plot.scatter(x='Lat',
                      y='Humidity',
                      c='RoyalBlue', marker="o", edgecolors="black", s = 40,  alpha=0.8, grid = True)

plt.title('Latitude vs. Humidity ')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
# Out:
# Text(0, 0.5, 'Humidity')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clean_city_data.plot.scatter(x='Lat',
                      y='Cloudiness',
                      c='RoyalBlue', marker="o", edgecolors="black", s = 40,  alpha=0.8, grid = True)

plt.title('Latitude vs. Cloudiness ')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
# Out:
# Text(0, 0.5, 'Cloudiness')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
clean_city_data.plot.scatter(x='Lat',
                      y='Wind Speed',
                      c='RoyalBlue', marker="o", edgecolors="black", s = 40,  alpha=0.8, grid = True)

plt.title('Latitude vs. Wind Speed ')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
# Out:
# Text(0, 0.5, 'Wind Speed')

# %% [markdown]
# ## Linear Regression

# %%
north_hemi = clean_city_data[clean_city_data["Lat"] > 0]
north_hemi = north_hemi.reset_index(drop=True)
north_hemi.head(20)
# Out:
#     City_ID            City Country        Date  Humidity    Lat    Long  \
# 0         0        Thompson      CA  1600382570        36  55.74  -97.86
# 1         1       Saskylakh      RU  1600382571        79  71.92  114.08
# 2         4       Galveston      US  1600382571        62  29.37  -94.97
# 3         6             Edd      ER  1600382572        67  13.93   41.69
# 4         8          Albany      US  1600382493        80  42.60  -73.97
# 5        12          Dikson      RU  1600382573        95  73.51   80.55
# 6        13          Bajmok      RS  1600382573        58  45.97   19.42
# 7        14           Atasū      KZ  1600382573        84  48.68   71.64
# 8        15           Kapaa      US  1600382573        58  22.08 -159.32
# 9        16       Kyzyl-Suu      KG  1600382574        78  42.34   78.00
# 10       18     San Quintín      MX  1600382574        29  30.48 -115.95
# 11       20          Barrow      US  1600382574        87  71.29 -156.79
# 12       22          Bantry      IE  1600382361        87  51.68   -9.45
# 13       23  Ribeira Grande      PT  1600382575        86  38.52  -28.70
# 14       24       Jamestown      US  1600382575        72  42.10  -79.24
# 15       25     Tuktoyaktuk      CA  1600382576        81  69.45 -133.04
# 16       27       Evinayong      GQ  1600382576        98   1.44   10.55
# 17       29          Harper      LR  1600382576        87   4.38   -7.72
# 18       30           Anaco      VE  1600382577        93   9.44  -64.47
# 19       31          Broome      US  1600382577        93  42.25  -75.83
#
#     Max Temp(F)  Cloudiness  Wind Speed
# 0         48.20          40       10.29
# 1         46.62           0        8.75
# 2         88.00          20        4.70
# 3         88.99          66        7.27
# 4         62.01         100        7.02
# 5         44.20         100        8.50
# 6         64.09          94       17.11
# 7         48.92          75       13.35
# 8         87.80          40       11.41
# 9         48.31          99        5.17
# 10        87.13          10       16.69
# 11        46.40          90        9.17
# 12        57.20           3       14.99
# 13        70.74         100       17.38
# 14        63.00          20        5.82
# 15        48.20          75        3.36
# 16        68.09          85        2.04
# 17        74.97         100       10.54
# 18        75.58          52        4.03
# 19        62.01          90        6.93

# %%
south_hemi = clean_city_data[clean_city_data["Lat"] < 0]
south_hemi = south_hemi.reset_index(drop=True)
south_hemi.head(20)
# Out:
#     City_ID             City Country        Date  Humidity    Lat    Long  \
# 0         2     Jacareacanga      BR  1600382571        41  -6.22  -57.75
# 1         3          Ushuaia      AR  1600382437        86 -54.80  -68.30
# 2         5          Rikitea      PF  1600382571        79 -23.12 -134.97
# 3         7     Punta Arenas      CL  1600382288        69 -53.15  -70.92
# 4         9  Arraial do Cabo      BR  1600382572        83 -22.97  -42.03
# 5        10        Hithadhoo      MV  1600382572        81  -0.60   73.08
# 6        11        Busselton      AU  1600382311        57 -33.65  115.33
# 7        17         Saldanha      ZA  1600382574        81 -33.01   17.94
# 8        19        Geraldton      AU  1600382574        75 -28.77  114.60
# 9        21        Cape Town      ZA  1600382342        93 -33.93   18.42
# 10       26           Touros      BR  1600382576        78  -5.20  -35.46
# 11       28   Saint-Philippe      RE  1600382576        63 -21.36   55.77
# 12       35      Charlestown      AU  1600382558        96 -32.95  151.67
# 13       43     Rondonópolis      BR  1600382580        24 -16.47  -54.64
# 14       45      Port Alfred      ZA  1600382580        75 -33.59   26.89
# 15       47    Mar del Plata      AR  1600382581        34 -38.00  -57.56
# 16       48         Hermanus      ZA  1600382581        93 -34.42   19.23
# 17       50           Faanui      PF  1600382581        75 -16.48 -151.75
# 18       52       Blackwater      AU  1600382430        51 -23.58  148.88
# 19       56      New Norfolk      AU  1600382583        67 -42.78  147.06
#
#     Max Temp(F)  Cloudiness  Wind Speed
# 0         87.80          65        2.51
# 1         33.80          75       26.40
# 2         72.12          86       21.61
# 3         37.40          40       34.45
# 4         73.40           0       13.87
# 5         82.13          81       11.32
# 6         46.99           0        9.60
# 7         51.80           0        2.24
# 8         46.40           0        6.93
# 9         52.00          18        2.24
# 10        77.00          20        9.17
# 11        66.00          48        6.93
# 12        63.00         100        1.01
# 13        86.00          59        5.61
# 14        58.95          20       10.22
# 15        64.40          30        9.17
# 16        45.00          33        4.21
# 17        79.03          71       17.09
# 18        71.46           5       13.02
# 19        43.00           0        1.01

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
from scipy.stats import linregress
from sklearn import datasets
import scipy.stats as sts

correlation = sts.pearsonr(north_hemi['Lat'], north_hemi['Max Temp(F)'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is -0.82
# The p-value is 1.7732298185697336e-84

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(north_hemi['Lat'], north_hemi['Max Temp(F)'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = north_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(north_hemi['Lat'],  north_hemi['Max Temp(F)'])

# Plot the regression line
plt.plot(north_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (10, 0), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp(F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.6684759666269403

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(south_hemi['Lat'], south_hemi['Max Temp(F)'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.79
# The p-value is 1.625683231555873e-33

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(south_hemi['Lat'], south_hemi['Max Temp(F)'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = south_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(south_hemi['Lat'],  south_hemi['Max Temp(F)'])

# Plot the regression line
plt.plot(south_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50, 25), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp(F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.6172945917188377

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(north_hemi['Lat'], north_hemi['Humidity'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.02
# The p-value is 0.7247754794736533

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(north_hemi['Lat'], north_hemi['Humidity'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = north_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(north_hemi['Lat'],  north_hemi['Humidity'])

# Plot the regression line
plt.plot(north_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (10, 30), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0003608164244388669

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(south_hemi['Lat'], south_hemi['Humidity'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.01
# The p-value is 0.8853288931587875

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(south_hemi['Lat'], south_hemi['Humidity'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = south_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(south_hemi['Lat'],  south_hemi['Humidity'])

# Plot the regression line
plt.plot(south_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50, 25), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0001372744771904735

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(north_hemi['Lat'], north_hemi['Cloudiness'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.14
# The p-value is 0.010714192759913355

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(north_hemi['Lat'], north_hemi['Cloudiness'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = north_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(north_hemi['Lat'],  north_hemi['Cloudiness'])

# Plot the regression line
plt.plot(north_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (10, 30), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.018779488297361622

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(south_hemi['Lat'], south_hemi['Cloudiness'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.02
# The p-value is 0.7989599124026524

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(south_hemi['Lat'], south_hemi['Cloudiness'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = south_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(south_hemi['Lat'],  south_hemi['Cloudiness'])

# Plot the regression line
plt.plot(south_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50, 25), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00042808239470438467

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(north_hemi['Lat'], north_hemi['Wind Speed'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.09
# The p-value is 0.10082401769298543

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(north_hemi['Lat'], north_hemi['Wind Speed'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = north_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(north_hemi['Lat'],  north_hemi['Wind Speed'])

# Plot the regression line
plt.plot(north_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (10, 8), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00780765772973992

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(south_hemi['Lat'], south_hemi['Wind Speed'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is -0.27
# The p-value is 0.0006298209274421158

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(south_hemi['Lat'], south_hemi['Wind Speed'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = south_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(south_hemi['Lat'],  south_hemi['Wind Speed'])

# Plot the regression line
plt.plot(south_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50 ,15), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.07423172163653087
