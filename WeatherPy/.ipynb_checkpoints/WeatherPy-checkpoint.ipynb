# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import requests
from random import uniform 
from pprint import pprint
from citipy import citipy
import pandas as pd
import os
import csv
import matplotlib.pyplot as plt

# Remember to update the config file with your API key
from config import api_key

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# ## Generate Cities List

# %%
cities = []
duplicate_cities = []

cities_name = []
latitudes = []
longititudes = []
max_temps = []
humidities = []
clouds = []
wind_speeds = []
countries = []
dates = []


print("Beginning Data Retrieval")
print("*"*40)

while len(cities_name) < 500:
    
    # generate a 500 unique latitude and longitude values
    
    long = round(uniform(-180,180), 3) #longitude ranges from -180 to 180
    lat = round(uniform(-90, 90), 3) #latitude ranges from -90 to 90
    #feed into citipy the lat, long coordinates to return as city object
    city = citipy.nearest_city(lat, long)
    city_name = city.city_name
    country_code = city.country_code
    # add the city and it's country code to the cities set
    city_entry = f"{city_name},{country_code}"
    if city_entry not in cities:
        cities.append(city_entry)
        print(f"city generated: {city_entry}")
        query_url = url + "appid=" + api_key + "&q=" + city_entry + "?" + "&units=metric"
        print(f"processing request for {city_entry}")

        weather_json = requests.get(query_url).json()
        if weather_json['cod'] == 200:
            cities_name.append(weather_json['name'])
            latitudes.append(weather_json['coord']['lat'])
            longititudes.append(weather_json['coord']['lon'])
            max_temps.append(weather_json['main']['temp_max'])
            humidities.append(weather_json['main']['humidity'])
            clouds.append(weather_json['clouds']['all'])
            wind_speeds.append(weather_json['wind']['speed'])
            countries.append(weather_json['sys']['country'])
            dates.append(weather_json['dt'])        
        else:
            print("City not found...skipping. \n")
            pass
    else:
        print(f"duplicate city: {city_entry}")
        duplicate_cities.append(city_entry)

print("*"*40)
print("End of Data Retrieval")
# Out:
# Beginning Data Retrieval
# ****************************************
# city generated: port alfred,za
# processing request for port alfred,za
# city generated: rikitea,pf
# processing request for rikitea,pf
# city generated: ancud,cl
# processing request for ancud,cl
# city generated: mataura,pf
# processing request for mataura,pf
# city generated: new norfolk,au
# processing request for new norfolk,au
# duplicate city: rikitea,pf
# city generated: mount gambier,au
# processing request for mount gambier,au
# city generated: caravelas,br
# processing request for caravelas,br
# city generated: roma,au
# processing request for roma,au
# city generated: mar del plata,ar
# processing request for mar del plata,ar
# city generated: cape town,za
# processing request for cape town,za
# city generated: grand forks,us
# processing request for grand forks,us
# city generated: tucupita,ve
# processing request for tucupita,ve
# city generated: kapaa,us
# processing request for kapaa,us
# city generated: qaanaaq,gl
# processing request for qaanaaq,gl
# city generated: padang,id
# processing request for padang,id
# city generated: atbasar,kz
# processing request for atbasar,kz
# duplicate city: qaanaaq,gl
# city generated: punta arenas,cl
# processing request for punta arenas,cl
# city generated: barrow,us
# processing request for barrow,us
# duplicate city: mataura,pf
# city generated: barentsburg,sj
# processing request for barentsburg,sj
# City not found...skipping.
#
# city generated: tuktoyaktuk,ca
# processing request for tuktoyaktuk,ca
# city generated: zemio,cf
# processing request for zemio,cf
# city generated: san rafael,ar
# processing request for san rafael,ar
# duplicate city: barrow,us
# city generated: simao,cn
# processing request for simao,cn
# city generated: axim,gh
# processing request for axim,gh
# city generated: fort collins,us
# processing request for fort collins,us
# city generated: san cristobal,ec
# processing request for san cristobal,ec
# city generated: taolanaro,mg
# processing request for taolanaro,mg
# City not found...skipping.
#
# city generated: tupik,ru
# processing request for tupik,ru
# duplicate city: barentsburg,sj
# city generated: hobart,au
# processing request for hobart,au
# city generated: araouane,ml
# processing request for araouane,ml
# city generated: bluff,nz
# processing request for bluff,nz
# city generated: alegrete,br
# processing request for alegrete,br
# city generated: airai,pw
# processing request for airai,pw
# city generated: la sarre,ca
# processing request for la sarre,ca
# city generated: illoqqortoormiut,gl
# processing request for illoqqortoormiut,gl
# City not found...skipping.
#
# duplicate city: barrow,us
# city generated: belushya guba,ru
# processing request for belushya guba,ru
# City not found...skipping.
#
# city generated: toliary,mg
# processing request for toliary,mg
# City not found...skipping.
#
# city generated: svetlogorsk,ru
# processing request for svetlogorsk,ru
# city generated: latur,in
# processing request for latur,in
# city generated: oxapampa,pe
# processing request for oxapampa,pe
# city generated: albany,au
# processing request for albany,au
# city generated: carnarvon,au
# processing request for carnarvon,au
# city generated: germersheim,de
# processing request for germersheim,de
# city generated: rabo de peixe,pt
# processing request for rabo de peixe,pt
# city generated: richards bay,za
# processing request for richards bay,za
# city generated: bethel,us
# processing request for bethel,us
# city generated: lagoa,pt
# processing request for lagoa,pt
# city generated: hofn,is
# processing request for hofn,is
# city generated: uruguaiana,br
# processing request for uruguaiana,br
# duplicate city: mataura,pf
# duplicate city: punta arenas,cl
# duplicate city: rikitea,pf
# duplicate city: mataura,pf
# city generated: makokou,ga
# processing request for makokou,ga
# city generated: nizhneyansk,ru
# processing request for nizhneyansk,ru
# City not found...skipping.
#
# city generated: georgetown,sh
# processing request for georgetown,sh
# duplicate city: albany,au
# city generated: horsham,au
# processing request for horsham,au
# duplicate city: belushya guba,ru
# city generated: ushuaia,ar
# processing request for ushuaia,ar
# city generated: hilo,us
# processing request for hilo,us
# city generated: cabo san lucas,mx
# processing request for cabo san lucas,mx
# duplicate city: ushuaia,ar
# city generated: longyearbyen,sj
# processing request for longyearbyen,sj
# duplicate city: taolanaro,mg
# city generated: asuncion nochixtlan,mx
# processing request for asuncion nochixtlan,mx
# city generated: flinders,au
# processing request for flinders,au
# duplicate city: new norfolk,au
# city generated: ca mau,vn
# processing request for ca mau,vn
# city generated: umm durman,sd
# processing request for umm durman,sd
# City not found...skipping.
#
# duplicate city: mataura,pf
# city generated: kamaishi,jp
# processing request for kamaishi,jp
# city generated: lebu,cl
# processing request for lebu,cl
# duplicate city: mataura,pf
# duplicate city: ushuaia,ar
# city generated: nikolskoye,ru
# processing request for nikolskoye,ru
# city generated: dikson,ru
# processing request for dikson,ru
# city generated: anadyr,ru
# processing request for anadyr,ru
# city generated: kintinku,tz
# processing request for kintinku,tz
# city generated: moose factory,ca
# processing request for moose factory,ca
# duplicate city: cape town,za
# city generated: busselton,au
# processing request for busselton,au
# city generated: pacifica,us
# processing request for pacifica,us
# city generated: dali,cn
# processing request for dali,cn
# city generated: paciran,id
# processing request for paciran,id
# city generated: cidreira,br
# processing request for cidreira,br
# city generated: dovers,vc
# processing request for dovers,vc
# city generated: port elizabeth,za
# processing request for port elizabeth,za
# city generated: madhyamgram,in
# processing request for madhyamgram,in
# city generated: ondorhaan,mn
# processing request for ondorhaan,mn
# City not found...skipping.
#
# city generated: lakota,ci
# processing request for lakota,ci
# city generated: hambantota,lk
# processing request for hambantota,lk
# duplicate city: busselton,au
# city generated: linxia,cn
# processing request for linxia,cn
# city generated: salinopolis,br
# processing request for salinopolis,br
# city generated: orapa,bw
# processing request for orapa,bw
# city generated: vaini,to
# processing request for vaini,to
# duplicate city: mataura,pf
# duplicate city: taolanaro,mg
# duplicate city: punta arenas,cl
# city generated: inhambane,mz
# processing request for inhambane,mz
# city generated: kiraoli,in
# processing request for kiraoli,in
# city generated: puerto ayora,ec
# processing request for puerto ayora,ec
# duplicate city: port alfred,za
# duplicate city: punta arenas,cl
# duplicate city: bethel,us
# duplicate city: port alfred,za
# duplicate city: punta arenas,cl
# duplicate city: airai,pw
# city generated: fortuna,us
# processing request for fortuna,us
# duplicate city: punta arenas,cl
# city generated: yellowknife,ca
# processing request for yellowknife,ca
# city generated: khasan,ru
# processing request for khasan,ru
# duplicate city: busselton,au
# city generated: saldanha,za
# processing request for saldanha,za
# city generated: kalianget,id
# processing request for kalianget,id
# duplicate city: mar del plata,ar
# duplicate city: taolanaro,mg
# duplicate city: mataura,pf
# duplicate city: hobart,au
# city generated: yar-sale,ru
# processing request for yar-sale,ru
# city generated: cacule,br
# processing request for cacule,br
# city generated: atchison,us
# processing request for atchison,us
# city generated: praia da vitoria,pt
# processing request for praia da vitoria,pt
# city generated: port hardy,ca
# processing request for port hardy,ca
# duplicate city: rikitea,pf
# duplicate city: barrow,us
# duplicate city: bluff,nz
# duplicate city: mataura,pf
# duplicate city: rikitea,pf
# duplicate city: puerto ayora,ec
# duplicate city: ushuaia,ar
# city generated: salaga,gh
# processing request for salaga,gh
# duplicate city: rikitea,pf
# city generated: jamestown,sh
# processing request for jamestown,sh
# city generated: abu samrah,qa
# processing request for abu samrah,qa
# city generated: burica,pa
# processing request for burica,pa
# City not found...skipping.
#
# city generated: olafsvik,is
# processing request for olafsvik,is
# duplicate city: ushuaia,ar
# duplicate city: qaanaaq,gl
# city generated: bad neustadt,de
# processing request for bad neustadt,de
# City not found...skipping.
#
# city generated: kaoma,zm
# processing request for kaoma,zm
# city generated: hermanus,za
# processing request for hermanus,za
# city generated: umzimvubu,za
# processing request for umzimvubu,za
# City not found...skipping.
#
# duplicate city: albany,au
# city generated: amderma,ru
# processing request for amderma,ru
# City not found...skipping.
#
# duplicate city: rikitea,pf
# city generated: daru,pg
# processing request for daru,pg
# city generated: upernavik,gl
# processing request for upernavik,gl
# city generated: namibe,ao
# processing request for namibe,ao
# duplicate city: belushya guba,ru
# city generated: iqaluit,ca
# processing request for iqaluit,ca
# duplicate city: cape town,za
# city generated: bardsir,ir
# processing request for bardsir,ir
# city generated: huron,us
# processing request for huron,us
# city generated: bredasdorp,za
# processing request for bredasdorp,za
# duplicate city: albany,au
# duplicate city: kapaa,us
# city generated: kampot,kh
# processing request for kampot,kh
# city generated: attawapiskat,ca
# processing request for attawapiskat,ca
# City not found...skipping.
#
# city generated: sambava,mg
# processing request for sambava,mg
# duplicate city: port alfred,za
# duplicate city: jamestown,sh
# duplicate city: hermanus,za
# duplicate city: mataura,pf
# city generated: qeshm,ir
# processing request for qeshm,ir
# city generated: okhotsk,ru
# processing request for okhotsk,ru
# duplicate city: mataura,pf
# duplicate city: taolanaro,mg
# city generated: beyneu,kz
# processing request for beyneu,kz
# city generated: avarua,ck
# processing request for avarua,ck
# city generated: lorengau,pg
# processing request for lorengau,pg
# duplicate city: rikitea,pf
# duplicate city: jamestown,sh
# duplicate city: bluff,nz
# duplicate city: belushya guba,ru
# city generated: ilulissat,gl
# processing request for ilulissat,gl
# city generated: ribeira grande,pt
# processing request for ribeira grande,pt
# duplicate city: albany,au
# duplicate city: jamestown,sh
# duplicate city: taolanaro,mg
# city generated: chapais,ca
# processing request for chapais,ca
# duplicate city: ancud,cl
# duplicate city: cape town,za
# duplicate city: rikitea,pf
# city generated: kirakira,sb
# processing request for kirakira,sb
# duplicate city: belushya guba,ru
# city generated: yamnytsya,ua
# processing request for yamnytsya,ua
# city generated: bay roberts,ca
# processing request for bay roberts,ca
# duplicate city: mount gambier,au
# city generated: mazagao,br
# processing request for mazagao,br
# city generated: hami,cn
# processing request for hami,cn
# duplicate city: albany,au
# duplicate city: mataura,pf
# duplicate city: longyearbyen,sj
# duplicate city: mataura,pf
# city generated: castro,cl
# processing request for castro,cl
# city generated: grand river south east,mu
# processing request for grand river south east,mu
# City not found...skipping.
#
# city generated: vaitupu,wf
# processing request for vaitupu,wf
# City not found...skipping.
#
# city generated: san quintin,mx
# processing request for san quintin,mx
# city generated: grude,ba
# processing request for grude,ba
# duplicate city: ilulissat,gl
# duplicate city: hermanus,za
# city generated: arraial do cabo,br
# processing request for arraial do cabo,br
# duplicate city: busselton,au
# city generated: kruisfontein,za
# processing request for kruisfontein,za
# duplicate city: rikitea,pf
# duplicate city: mataura,pf
# city generated: vestmanna,fo
# processing request for vestmanna,fo
# city generated: leningradskiy,ru
# processing request for leningradskiy,ru
# city generated: panaba,mx
# processing request for panaba,mx
# duplicate city: qaanaaq,gl
# duplicate city: kapaa,us
# duplicate city: cape town,za
# duplicate city: port alfred,za
# duplicate city: busselton,au
# city generated: zinder,ne
# processing request for zinder,ne
# city generated: ponta delgada,pt
# processing request for ponta delgada,pt
# duplicate city: castro,cl
# duplicate city: hermanus,za
# city generated: chadan,ru
# processing request for chadan,ru
# city generated: buala,sb
# processing request for buala,sb
# city generated: mugur-aksy,ru
# processing request for mugur-aksy,ru
# city generated: sisimiut,gl
# processing request for sisimiut,gl
# duplicate city: busselton,au
# duplicate city: ushuaia,ar
# duplicate city: punta arenas,cl
# duplicate city: dikson,ru
# city generated: sampit,id
# processing request for sampit,id
# duplicate city: port alfred,za
# duplicate city: bredasdorp,za
# duplicate city: castro,cl
# duplicate city: busselton,au
# duplicate city: avarua,ck
# city generated: wolmaranstad,za
# processing request for wolmaranstad,za
# City not found...skipping.
#
# city generated: thompson,ca
# processing request for thompson,ca
# city generated: cabedelo,br
# processing request for cabedelo,br
# duplicate city: rikitea,pf
# duplicate city: cape town,za
# city generated: naze,jp
# processing request for naze,jp
# city generated: nantucket,us
# processing request for nantucket,us
# duplicate city: mataura,pf
# city generated: dalvik,is
# processing request for dalvik,is
# city generated: port-gentil,ga
# processing request for port-gentil,ga
# city generated: slavyanka,ru
# processing request for slavyanka,ru
# duplicate city: cape town,za
# city generated: rafsanjan,ir
# processing request for rafsanjan,ir
# duplicate city: ushuaia,ar
# duplicate city: bluff,nz
# duplicate city: cabo san lucas,mx
# city generated: saskylakh,ru
# processing request for saskylakh,ru
# duplicate city: castro,cl
# duplicate city: hami,cn
# duplicate city: jamestown,sh
# duplicate city: ancud,cl
# city generated: havoysund,no
# processing request for havoysund,no
# duplicate city: port hardy,ca
# city generated: marinette,us
# processing request for marinette,us
# city generated: chuy,uy
# processing request for chuy,uy
# city generated: kenai,us
# processing request for kenai,us
# city generated: tinguindin,mx
# processing request for tinguindin,mx
# city generated: vrangel,ru
# processing request for vrangel,ru
# duplicate city: kapaa,us
# duplicate city: upernavik,gl
# city generated: kodiak,us
# processing request for kodiak,us
# city generated: atuona,pf
# processing request for atuona,pf
# city generated: osypenko,ua
# processing request for osypenko,ua
# city generated: bengkulu,id
# processing request for bengkulu,id
# city generated: comodoro rivadavia,ar
# processing request for comodoro rivadavia,ar
# duplicate city: hilo,us
# duplicate city: albany,au
# city generated: husavik,is
# processing request for husavik,is
# duplicate city: bredasdorp,za
# city generated: bambous virieux,mu
# processing request for bambous virieux,mu
# duplicate city: rikitea,pf
# city generated: carbonia,it
# processing request for carbonia,it
# duplicate city: iqaluit,ca
# city generated: artyk,ru
# processing request for artyk,ru
# City not found...skipping.
#
# city generated: karratha,au
# processing request for karratha,au
# city generated: norman wells,ca
# processing request for norman wells,ca
# city generated: alyangula,au
# processing request for alyangula,au
# duplicate city: bethel,us
# duplicate city: lagoa,pt
# city generated: nadym,ru
# processing request for nadym,ru
# duplicate city: punta arenas,cl
# duplicate city: punta arenas,cl
# city generated: tommot,ru
# processing request for tommot,ru
# city generated: cherskiy,ru
# processing request for cherskiy,ru
# duplicate city: port alfred,za
# city generated: benghazi,ly
# processing request for benghazi,ly
# duplicate city: ushuaia,ar
# city generated: shellbrook,ca
# processing request for shellbrook,ca
# city generated: talcahuano,cl
# processing request for talcahuano,cl
# duplicate city: belushya guba,ru
# city generated: lavrentiya,ru
# processing request for lavrentiya,ru
# duplicate city: kapaa,us
# city generated: vardo,no
# processing request for vardo,no
# duplicate city: vaini,to
# city generated: kulhudhuffushi,mv
# processing request for kulhudhuffushi,mv
# city generated: luwuk,id
# processing request for luwuk,id
# duplicate city: puerto ayora,ec
# duplicate city: hermanus,za
# duplicate city: hami,cn
# city generated: kharp,ru
# processing request for kharp,ru
# city generated: sentyabrskiy,ru
# processing request for sentyabrskiy,ru
# City not found...skipping.
#
# city generated: baykit,ru
# processing request for baykit,ru
# city generated: port keats,au
# processing request for port keats,au
# city generated: inirida,co
# processing request for inirida,co
# duplicate city: saskylakh,ru
# city generated: sayyan,ye
# processing request for sayyan,ye
# duplicate city: cape town,za
# duplicate city: ushuaia,ar
# duplicate city: grand river south east,mu
# city generated: westport,ie
# processing request for westport,ie
# duplicate city: inhambane,mz
# duplicate city: mataura,pf
# duplicate city: kodiak,us
# duplicate city: port elizabeth,za
# city generated: nokaneng,bw
# processing request for nokaneng,bw
# duplicate city: georgetown,sh
# city generated: namatanai,pg
# processing request for namatanai,pg
# duplicate city: kruisfontein,za
# city generated: berlevag,no
# processing request for berlevag,no
# duplicate city: bluff,nz
# duplicate city: busselton,au
# city generated: penha,br
# processing request for penha,br
# city generated: tasiilaq,gl
# processing request for tasiilaq,gl
# city generated: yemelyanovo,ru
# processing request for yemelyanovo,ru
# duplicate city: taolanaro,mg
# city generated: micheldorf,at
# processing request for micheldorf,at
# duplicate city: rikitea,pf
# city generated: mys shmidta,ru
# processing request for mys shmidta,ru
# City not found...skipping.
#
# duplicate city: port alfred,za
# duplicate city: hobart,au
# duplicate city: ushuaia,ar
# duplicate city: albany,au
# city generated: samalaeulu,ws
# processing request for samalaeulu,ws
# City not found...skipping.
#
# duplicate city: ushuaia,ar
# city generated: aquiraz,br
# processing request for aquiraz,br
# city generated: kavaratti,in
# processing request for kavaratti,in
# duplicate city: port alfred,za
# city generated: nanortalik,gl
# processing request for nanortalik,gl
# duplicate city: kapaa,us
# city generated: toba,jp
# processing request for toba,jp
# duplicate city: tuktoyaktuk,ca
# city generated: maniitsoq,gl
# processing request for maniitsoq,gl
# city generated: mae chan,th
# processing request for mae chan,th
# duplicate city: hami,cn
# duplicate city: atuona,pf
# duplicate city: hilo,us
# duplicate city: albany,au
# city generated: kuche,cn
# processing request for kuche,cn
# City not found...skipping.
#
# duplicate city: rikitea,pf
# city generated: khatanga,ru
# processing request for khatanga,ru
# duplicate city: tuktoyaktuk,ca
# city generated: geraldton,au
# processing request for geraldton,au
# city generated: thuro,dk
# processing request for thuro,dk
# City not found...skipping.
#
# duplicate city: georgetown,sh
# city generated: katsuura,jp
# processing request for katsuura,jp
# city generated: sundsvall,se
# processing request for sundsvall,se
# duplicate city: ca mau,vn
# city generated: atambua,id
# processing request for atambua,id
# city generated: la tuque,ca
# processing request for la tuque,ca
# duplicate city: iqaluit,ca
# city generated: inuvik,ca
# processing request for inuvik,ca
# city generated: xalpatlahuac,mx
# processing request for xalpatlahuac,mx
# duplicate city: bluff,nz
# city generated: resistencia,ar
# processing request for resistencia,ar
# city generated: panjab,af
# processing request for panjab,af
# city generated: awbari,ly
# processing request for awbari,ly
# duplicate city: castro,cl
# city generated: sinnamary,gf
# processing request for sinnamary,gf
# duplicate city: taolanaro,mg
# duplicate city: kapaa,us
# city generated: butaritari,ki
# processing request for butaritari,ki
# city generated: tongchuan,cn
# processing request for tongchuan,cn
# duplicate city: cape town,za
# duplicate city: ushuaia,ar
# city generated: samarai,pg
# processing request for samarai,pg
# duplicate city: new norfolk,au
# city generated: portland,au
# processing request for portland,au
# duplicate city: barentsburg,sj
# city generated: ponta do sol,cv
# processing request for ponta do sol,cv
# city generated: meulaboh,id
# processing request for meulaboh,id
# duplicate city: ancud,cl
# city generated: bamiantong,cn
# processing request for bamiantong,cn
# city generated: impfondo,cg
# processing request for impfondo,cg
# city generated: viedma,ar
# processing request for viedma,ar
# duplicate city: rikitea,pf
# city generated: thunder bay,ca
# processing request for thunder bay,ca
# duplicate city: mataura,pf
# city generated: seoul,kr
# processing request for seoul,kr
# city generated: chokurdakh,ru
# processing request for chokurdakh,ru
# duplicate city: norman wells,ca
# city generated: severo-kurilsk,ru
# processing request for severo-kurilsk,ru
# city generated: suoyarvi,ru
# processing request for suoyarvi,ru
# duplicate city: illoqqortoormiut,gl
# city generated: blackwater,au
# processing request for blackwater,au
# city generated: punta cardon,ve
# processing request for punta cardon,ve
# city generated: ahuimanu,us
# processing request for ahuimanu,us
# duplicate city: bluff,nz
# city generated: hearst,ca
# processing request for hearst,ca
# city generated: ventspils,lv
# processing request for ventspils,lv
# duplicate city: albany,au
# city generated: shingu,jp
# processing request for shingu,jp
# city generated: kishtwar,in
# processing request for kishtwar,in
# duplicate city: cape town,za
# city generated: stornoway,gb
# processing request for stornoway,gb
# duplicate city: khatanga,ru
# city generated: bara,sd
# processing request for bara,sd
# duplicate city: katsuura,jp
# duplicate city: mataura,pf
# city generated: montgomery,us
# processing request for montgomery,us
# city generated: sitka,us
# processing request for sitka,us
# city generated: levelland,us
# processing request for levelland,us
# duplicate city: butaritari,ki
# city generated: valleyview,ca
# processing request for valleyview,ca
# city generated: lephepe,bw
# processing request for lephepe,bw
# City not found...skipping.
#
# duplicate city: nikolskoye,ru
# duplicate city: san quintin,mx
# city generated: griffith,au
# processing request for griffith,au
# city generated: providencia,mx
# processing request for providencia,mx
# city generated: russell,nz
# processing request for russell,nz
# duplicate city: albany,au
# duplicate city: ushuaia,ar
# city generated: campbell river,ca
# processing request for campbell river,ca
# duplicate city: cidreira,br
# city generated: smithers,ca
# processing request for smithers,ca
# city generated: guerrero negro,mx
# processing request for guerrero negro,mx
# duplicate city: anadyr,ru
# duplicate city: port elizabeth,za
# duplicate city: vaini,to
# city generated: salalah,om
# processing request for salalah,om
# city generated: horta,pt
# processing request for horta,pt
# duplicate city: albany,au
# duplicate city: butaritari,ki
# duplicate city: ca mau,vn
# duplicate city: dikson,ru
# duplicate city: bluff,nz
# city generated: nha trang,vn
# processing request for nha trang,vn
# duplicate city: husavik,is
# city generated: aviles,es
# processing request for aviles,es
# city generated: doka,sd
# processing request for doka,sd
# city generated: san isidro,ph
# processing request for san isidro,ph
# city generated: olinda,br
# processing request for olinda,br
# city generated: luderitz,na
# processing request for luderitz,na
# city generated: srednekolymsk,ru
# processing request for srednekolymsk,ru
# city generated: dakar,sn
# processing request for dakar,sn
# duplicate city: lorengau,pg
# city generated: tabuk,sa
# processing request for tabuk,sa
# duplicate city: atuona,pf
# duplicate city: lorengau,pg
# duplicate city: arraial do cabo,br
# duplicate city: saskylakh,ru
# city generated: yulara,au
# processing request for yulara,au
# city generated: juneau,us
# processing request for juneau,us
# city generated: victoria,sc
# processing request for victoria,sc
# city generated: hasaki,jp
# processing request for hasaki,jp
# duplicate city: taolanaro,mg
# duplicate city: barentsburg,sj
# city generated: coihaique,cl
# processing request for coihaique,cl
# duplicate city: busselton,au
# duplicate city: port alfred,za
# city generated: caxito,ao
# processing request for caxito,ao
# city generated: tsihombe,mg
# processing request for tsihombe,mg
# City not found...skipping.
#
# duplicate city: namibe,ao
# duplicate city: busselton,au
# city generated: diamantino,br
# processing request for diamantino,br
# duplicate city: ushuaia,ar
# duplicate city: toliary,mg
# city generated: makakilo city,us
# processing request for makakilo city,us
# duplicate city: qaanaaq,gl
# duplicate city: cabedelo,br
# city generated: tuggurt,dz
# processing request for tuggurt,dz
# City not found...skipping.
#
# city generated: svirsk,ru
# processing request for svirsk,ru
# city generated: saint-philippe,re
# processing request for saint-philippe,re
# city generated: fairview,ca
# processing request for fairview,ca
# duplicate city: hermanus,za
# city generated: yumen,cn
# processing request for yumen,cn
# duplicate city: mataura,pf
# duplicate city: amderma,ru
# duplicate city: cape town,za
# duplicate city: ushuaia,ar
# duplicate city: fortuna,us
# city generated: mahebourg,mu
# processing request for mahebourg,mu
# duplicate city: ushuaia,ar
# duplicate city: chokurdakh,ru
# city generated: saurimo,ao
# processing request for saurimo,ao
# city generated: urdzhar,kz
# processing request for urdzhar,kz
# City not found...skipping.
#
# duplicate city: bredasdorp,za
# duplicate city: fortuna,us
# city generated: praya,id
# processing request for praya,id
# duplicate city: jamestown,sh
# city generated: alofi,nu
# processing request for alofi,nu
# duplicate city: thompson,ca
# city generated: batemans bay,au
# processing request for batemans bay,au
# duplicate city: barentsburg,sj
# city generated: karkaralinsk,kz
# processing request for karkaralinsk,kz
# City not found...skipping.
#
# city generated: utiroa,ki
# processing request for utiroa,ki
# City not found...skipping.
#
# duplicate city: rikitea,pf
# city generated: dharchula,in
# processing request for dharchula,in
# duplicate city: upernavik,gl
# duplicate city: mataura,pf
# city generated: andira,br
# processing request for andira,br
# duplicate city: rikitea,pf
# city generated: rawannawi,ki
# processing request for rawannawi,ki
# City not found...skipping.
#
# duplicate city: yar-sale,ru
# duplicate city: attawapiskat,ca
# city generated: saleaula,ws
# processing request for saleaula,ws
# City not found...skipping.
#
# duplicate city: busselton,au
# city generated: rio gallegos,ar
# processing request for rio gallegos,ar
# city generated: lamar,us
# processing request for lamar,us
# city generated: mecca,sa
# processing request for mecca,sa
# city generated: aksarka,ru
# processing request for aksarka,ru
# duplicate city: yellowknife,ca
# city generated: emba,kz
# processing request for emba,kz
# duplicate city: albany,au
# duplicate city: arraial do cabo,br
# city generated: hithadhoo,mv
# processing request for hithadhoo,mv
# city generated: la orilla,mx
# processing request for la orilla,mx
# duplicate city: taolanaro,mg
# city generated: hervey bay,au
# processing request for hervey bay,au
# city generated: malumfashi,ng
# processing request for malumfashi,ng
# duplicate city: rikitea,pf
# city generated: tuatapere,nz
# processing request for tuatapere,nz
# city generated: malatya,tr
# processing request for malatya,tr
# city generated: astipalaia,gr
# processing request for astipalaia,gr
# City not found...skipping.
#
# city generated: dolzhanskaya,ru
# processing request for dolzhanskaya,ru
# city generated: laguna,br
# processing request for laguna,br
# duplicate city: khatanga,ru
# city generated: brasy,cz
# processing request for brasy,cz
# duplicate city: fortuna,us
# city generated: girona,es
# processing request for girona,es
# city generated: xingyi,cn
# processing request for xingyi,cn
# duplicate city: port elizabeth,za
# city generated: dubrovka,ru
# processing request for dubrovka,ru
# duplicate city: butaritari,ki
# duplicate city: cape town,za
# duplicate city: barrow,us
# duplicate city: abu samrah,qa
# duplicate city: lagoa,pt
# duplicate city: viedma,ar
# duplicate city: saint-philippe,re
# city generated: tumannyy,ru
# processing request for tumannyy,ru
# City not found...skipping.
#
# city generated: xinzhi,cn
# processing request for xinzhi,cn
# duplicate city: bluff,nz
# duplicate city: vaini,to
# duplicate city: cape town,za
# city generated: itoman,jp
# processing request for itoman,jp
# city generated: tuy hoa,vn
# processing request for tuy hoa,vn
# duplicate city: thompson,ca
# duplicate city: padang,id
# duplicate city: mar del plata,ar
# duplicate city: mataura,pf
# city generated: pitimbu,br
# processing request for pitimbu,br
# city generated: karauzyak,uz
# processing request for karauzyak,uz
# City not found...skipping.
#
# duplicate city: cherskiy,ru
# city generated: sao filipe,cv
# processing request for sao filipe,cv
# duplicate city: new norfolk,au
# duplicate city: port elizabeth,za
# city generated: ambilobe,mg
# processing request for ambilobe,mg
# city generated: praia,cv
# processing request for praia,cv
# duplicate city: atuona,pf
# duplicate city: luderitz,na
# duplicate city: mahebourg,mu
# city generated: mazatlan,mx
# processing request for mazatlan,mx
# duplicate city: bambous virieux,mu
# duplicate city: khatanga,ru
# city generated: cayenne,gf
# processing request for cayenne,gf
# duplicate city: butaritari,ki
# city generated: puerto colombia,co
# processing request for puerto colombia,co
# duplicate city: butaritari,ki
# duplicate city: cabo san lucas,mx
# city generated: faanui,pf
# processing request for faanui,pf
# city generated: perth,au
# processing request for perth,au
# duplicate city: mahebourg,mu
# duplicate city: albany,au
# city generated: dingle,ie
# processing request for dingle,ie
# city generated: rodrigues alves,br
# processing request for rodrigues alves,br
# city generated: manthani,in
# processing request for manthani,in
# city generated: ambon,id
# processing request for ambon,id
# duplicate city: chapais,ca
# duplicate city: nikolskoye,ru
# city generated: boda,cf
# processing request for boda,cf
# duplicate city: salalah,om
# duplicate city: avarua,ck
# duplicate city: hilo,us
# city generated: mackay,au
# processing request for mackay,au
# city generated: klyuchi,ru
# processing request for klyuchi,ru
# city generated: matara,lk
# processing request for matara,lk
# duplicate city: vaini,to
# city generated: coahuayana,mx
# processing request for coahuayana,mx
# duplicate city: kodiak,us
# duplicate city: attawapiskat,ca
# duplicate city: avarua,ck
# duplicate city: airai,pw
# city generated: lompoc,us
# processing request for lompoc,us
# duplicate city: hilo,us
# duplicate city: hobart,au
# city generated: palabuhanratu,id
# processing request for palabuhanratu,id
# City not found...skipping.
#
# duplicate city: shellbrook,ca
# duplicate city: nizhneyansk,ru
# duplicate city: rikitea,pf
# duplicate city: coihaique,cl
# duplicate city: katsuura,jp
# duplicate city: busselton,au
# city generated: chumikan,ru
# processing request for chumikan,ru
# duplicate city: cape town,za
# duplicate city: mataura,pf
# duplicate city: portland,au
# duplicate city: ponta do sol,cv
# city generated: nelson bay,au
# processing request for nelson bay,au
# city generated: boralday,kz
# processing request for boralday,kz
# city generated: coquimbo,cl
# processing request for coquimbo,cl
# city generated: talakan,ru
# processing request for talakan,ru
# duplicate city: hilo,us
# city generated: syava,ru
# processing request for syava,ru
# duplicate city: dikson,ru
# city generated: pevek,ru
# processing request for pevek,ru
# duplicate city: tuktoyaktuk,ca
# duplicate city: thompson,ca
# duplicate city: barentsburg,sj
# duplicate city: ushuaia,ar
# duplicate city: hobart,au
# duplicate city: punta arenas,cl
# duplicate city: castro,cl
# city generated: jakar,bt
# processing request for jakar,bt
# duplicate city: cape town,za
# duplicate city: punta arenas,cl
# city generated: vallenar,cl
# processing request for vallenar,cl
# duplicate city: albany,au
# city generated: loreto,mx
# processing request for loreto,mx
# duplicate city: puerto ayora,ec
# duplicate city: mataura,pf
# city generated: hovd,mn
# processing request for hovd,mn
# duplicate city: shingu,jp
# duplicate city: tuktoyaktuk,ca
# duplicate city: port alfred,za
# city generated: igarka,ru
# processing request for igarka,ru
# city generated: oranjemund,na
# processing request for oranjemund,na
# duplicate city: cape town,za
# duplicate city: albany,au
# duplicate city: pevek,ru
# city generated: los llanos de aridane,es
# processing request for los llanos de aridane,es
# duplicate city: longyearbyen,sj
# duplicate city: tsihombe,mg
# duplicate city: bluff,nz
# duplicate city: chokurdakh,ru
# city generated: chimalpa,mx
# processing request for chimalpa,mx
# city generated: santiago,ph
# processing request for santiago,ph
# duplicate city: coquimbo,cl
# city generated: tura,ru
# processing request for tura,ru
# city generated: east london,za
# processing request for east london,za
# duplicate city: tsihombe,mg
# city generated: novaci,ro
# processing request for novaci,ro
# duplicate city: bluff,nz
# duplicate city: airai,pw
# duplicate city: hilo,us
# duplicate city: dikson,ru
# duplicate city: mataura,pf
# duplicate city: rikitea,pf
# city generated: aasiaat,gl
# processing request for aasiaat,gl
# duplicate city: ilulissat,gl
# duplicate city: fortuna,us
# city generated: vung tau,vn
# processing request for vung tau,vn
# duplicate city: albany,au
# duplicate city: port alfred,za
# city generated: kiama,au
# processing request for kiama,au
# duplicate city: rikitea,pf
# duplicate city: ushuaia,ar
# duplicate city: kapaa,us
# city generated: aykhal,ru
# processing request for aykhal,ru
# city generated: sault sainte marie,ca
# processing request for sault sainte marie,ca
# duplicate city: praia,cv
# city generated: asyut,eg
# processing request for asyut,eg
# city generated: kahului,us
# processing request for kahului,us
# duplicate city: cape town,za
# duplicate city: salalah,om
# duplicate city: port elizabeth,za
# duplicate city: cabo san lucas,mx
# duplicate city: los llanos de aridane,es
# duplicate city: ushuaia,ar
# duplicate city: ushuaia,ar
# city generated: jiexiu,cn
# processing request for jiexiu,cn
# duplicate city: cabo san lucas,mx
# duplicate city: mataura,pf
# city generated: obama,jp
# processing request for obama,jp
# duplicate city: albany,au
# duplicate city: punta arenas,cl
# duplicate city: yellowknife,ca
# duplicate city: lebu,cl
# duplicate city: tsihombe,mg
# duplicate city: rikitea,pf
# duplicate city: rikitea,pf
# duplicate city: taolanaro,mg
# city generated: bathsheba,bb
# processing request for bathsheba,bb
# duplicate city: mataura,pf
# duplicate city: mar del plata,ar
# city generated: payo,ph
# processing request for payo,ph
# duplicate city: rikitea,pf
# city generated: uglovskoye,ru
# processing request for uglovskoye,ru
# city generated: dorogobuzh,ru
# processing request for dorogobuzh,ru
# duplicate city: jamestown,sh
# duplicate city: albany,au
# city generated: muroto,jp
# processing request for muroto,jp
# city generated: ribas do rio pardo,br
# processing request for ribas do rio pardo,br
# city generated: antofagasta,cl
# processing request for antofagasta,cl
# duplicate city: tuktoyaktuk,ca
# duplicate city: samarai,pg
# city generated: prado,br
# processing request for prado,br
# city generated: ixtapa,mx
# processing request for ixtapa,mx
# duplicate city: barentsburg,sj
# duplicate city: butaritari,ki
# duplicate city: busselton,au
# city generated: gurgan,az
# processing request for gurgan,az
# City not found...skipping.
#
# duplicate city: punta arenas,cl
# duplicate city: ushuaia,ar
# duplicate city: iqaluit,ca
# duplicate city: rio gallegos,ar
# duplicate city: butaritari,ki
# duplicate city: mataura,pf
# city generated: teya,ru
# processing request for teya,ru
# duplicate city: puerto ayora,ec
# duplicate city: rikitea,pf
# duplicate city: sisimiut,gl
# city generated: santa isabel do rio negro,br
# processing request for santa isabel do rio negro,br
# city generated: pechenga,ru
# processing request for pechenga,ru
# duplicate city: qaanaaq,gl
# duplicate city: yellowknife,ca
# duplicate city: hilo,us
# duplicate city: barrow,us
# city generated: esperance,au
# processing request for esperance,au
# city generated: grand gaube,mu
# processing request for grand gaube,mu
# duplicate city: bredasdorp,za
# city generated: saint-raymond,ca
# processing request for saint-raymond,ca
# city generated: pisco,pe
# processing request for pisco,pe
# city generated: oussouye,sn
# processing request for oussouye,sn
# duplicate city: kapaa,us
# duplicate city: bredasdorp,za
# duplicate city: hobart,au
# city generated: henties bay,na
# processing request for henties bay,na
# duplicate city: avarua,ck
# city generated: kieta,pg
# processing request for kieta,pg
# city generated: palora,ec
# processing request for palora,ec
# duplicate city: kirakira,sb
# duplicate city: punta arenas,cl
# city generated: kyabe,td
# processing request for kyabe,td
# city generated: bracigovo,bg
# processing request for bracigovo,bg
# City not found...skipping.
#
# duplicate city: busselton,au
# duplicate city: rikitea,pf
# city generated: tlapa,mx
# processing request for tlapa,mx
# City not found...skipping.
#
# city generated: killybegs,ie
# processing request for killybegs,ie
# duplicate city: taolanaro,mg
# duplicate city: amderma,ru
# city generated: sulangan,ph
# processing request for sulangan,ph
# city generated: krasnogorskiy,ru
# processing request for krasnogorskiy,ru
# city generated: bandarbeyla,so
# processing request for bandarbeyla,so
# city generated: ferrol,es
# processing request for ferrol,es
# city generated: constitucion,mx
# processing request for constitucion,mx
# city generated: teguise,es
# processing request for teguise,es
# city generated: isla mujeres,mx
# processing request for isla mujeres,mx
# duplicate city: barrow,us
# duplicate city: puerto ayora,ec
# duplicate city: mount gambier,au
# duplicate city: rikitea,pf
# duplicate city: kapaa,us
# city generated: cockburn town,bs
# processing request for cockburn town,bs
# duplicate city: ushuaia,ar
# city generated: khonsa,in
# processing request for khonsa,in
# city generated: utete,tz
# processing request for utete,tz
# city generated: igrim,ru
# processing request for igrim,ru
# duplicate city: avarua,ck
# city generated: codrington,ag
# processing request for codrington,ag
# city generated: fairbanks,us
# processing request for fairbanks,us
# city generated: bosaso,so
# processing request for bosaso,so
# city generated: auki,sb
# processing request for auki,sb
# city generated: umm lajj,sa
# processing request for umm lajj,sa
# city generated: deep river,ca
# processing request for deep river,ca
# city generated: hokitika,nz
# processing request for hokitika,nz
# city generated: yabrud,sy
# processing request for yabrud,sy
# duplicate city: luderitz,na
# city generated: suntar,ru
# processing request for suntar,ru
# duplicate city: mys shmidta,ru
# duplicate city: mataura,pf
# duplicate city: hobart,au
# duplicate city: fortuna,us
# city generated: beringovskiy,ru
# processing request for beringovskiy,ru
# city generated: seabra,br
# processing request for seabra,br
# duplicate city: castro,cl
# duplicate city: port alfred,za
# city generated: qujing,cn
# processing request for qujing,cn
# duplicate city: bredasdorp,za
# duplicate city: chuy,uy
# city generated: dunedin,nz
# processing request for dunedin,nz
# city generated: marquette,us
# processing request for marquette,us
# duplicate city: saint-philippe,re
# city generated: solano,co
# processing request for solano,co
# city generated: egvekinot,ru
# processing request for egvekinot,ru
# city generated: san patricio,mx
# processing request for san patricio,mx
# city generated: half moon bay,us
# processing request for half moon bay,us
# duplicate city: punta arenas,cl
# duplicate city: grand gaube,mu
# duplicate city: mataura,pf
# duplicate city: mataura,pf
# duplicate city: faanui,pf
# city generated: aklavik,ca
# processing request for aklavik,ca
# city generated: makinsk,kz
# processing request for makinsk,kz
# duplicate city: mar del plata,ar
# duplicate city: daru,pg
# duplicate city: albany,au
# city generated: puerto del rosario,es
# processing request for puerto del rosario,es
# city generated: poum,nc
# processing request for poum,nc
# duplicate city: ushuaia,ar
# duplicate city: mahebourg,mu
# duplicate city: vaini,to
# duplicate city: vaini,to
# city generated: makubetsu,jp
# processing request for makubetsu,jp
# duplicate city: port alfred,za
# duplicate city: port elizabeth,za
# duplicate city: rikitea,pf
# duplicate city: atuona,pf
# duplicate city: tasiilaq,gl
# city generated: calbuco,cl
# processing request for calbuco,cl
# duplicate city: vaini,to
# duplicate city: tasiilaq,gl
# duplicate city: san patricio,mx
# duplicate city: bluff,nz
# duplicate city: atuona,pf
# duplicate city: rikitea,pf
# city generated: sao joao da barra,br
# processing request for sao joao da barra,br
# city generated: niquelandia,br
# processing request for niquelandia,br
# city generated: pangody,ru
# processing request for pangody,ru
# duplicate city: hithadhoo,mv
# duplicate city: severo-kurilsk,ru
# city generated: campeche,mx
# processing request for campeche,mx
# duplicate city: saskylakh,ru
# duplicate city: port elizabeth,za
# duplicate city: naze,jp
# duplicate city: henties bay,na
# duplicate city: qaanaaq,gl
# city generated: adrar,dz
# processing request for adrar,dz
# duplicate city: vaitupu,wf
# city generated: craigieburn,au
# processing request for craigieburn,au
# duplicate city: punta arenas,cl
# duplicate city: busselton,au
# city generated: launceston,au
# processing request for launceston,au
# duplicate city: nizhneyansk,ru
# duplicate city: vallenar,cl
# city generated: nouna,bf
# processing request for nouna,bf
# duplicate city: kodiak,us
# duplicate city: ushuaia,ar
# duplicate city: punta arenas,cl
# duplicate city: dikson,ru
# duplicate city: bredasdorp,za
# city generated: haines junction,ca
# processing request for haines junction,ca
# duplicate city: mataura,pf
# city generated: road town,vg
# processing request for road town,vg
# duplicate city: thompson,ca
# duplicate city: ushuaia,ar
# duplicate city: nizhneyansk,ru
# duplicate city: mataura,pf
# city generated: torbay,ca
# processing request for torbay,ca
# city generated: mundargi,in
# processing request for mundargi,in
# duplicate city: ambon,id
# city generated: consolacion del sur,cu
# processing request for consolacion del sur,cu
# duplicate city: la tuque,ca
# city generated: daxian,cn
# processing request for daxian,cn
# City not found...skipping.
#
# duplicate city: bluff,nz
# duplicate city: rikitea,pf
# duplicate city: rikitea,pf
# city generated: raga,sd
# processing request for raga,sd
# duplicate city: hermanus,za
# city generated: mahaicony,gy
# processing request for mahaicony,gy
# City not found...skipping.
#
# city generated: bajil,ye
# processing request for bajil,ye
# duplicate city: hermanus,za
# city generated: shakawe,bw
# processing request for shakawe,bw
# duplicate city: barrow,us
# city generated: montepuez,mz
# processing request for montepuez,mz
# duplicate city: mar del plata,ar
# duplicate city: rikitea,pf
# duplicate city: barrow,us
# duplicate city: saskylakh,ru
# duplicate city: faanui,pf
# duplicate city: yellowknife,ca
# city generated: bielsko-biala,pl
# processing request for bielsko-biala,pl
# duplicate city: vaini,to
# duplicate city: amderma,ru
# duplicate city: punta arenas,cl
# city generated: arman,ru
# processing request for arman,ru
# city generated: north bend,us
# processing request for north bend,us
# duplicate city: kapaa,us
# city generated: rincon,us
# processing request for rincon,us
# duplicate city: cape town,za
# duplicate city: cape town,za
# city generated: tecoanapa,mx
# processing request for tecoanapa,mx
# duplicate city: rikitea,pf
# duplicate city: bredasdorp,za
# duplicate city: mount gambier,au
# city generated: kununurra,au
# processing request for kununurra,au
# duplicate city: praia,cv
# city generated: heihe,cn
# processing request for heihe,cn
# city generated: malwan,in
# processing request for malwan,in
# City not found...skipping.
#
# duplicate city: coquimbo,cl
# duplicate city: barentsburg,sj
# duplicate city: busselton,au
# city generated: nichinan,jp
# processing request for nichinan,jp
# duplicate city: mataura,pf
# duplicate city: illoqqortoormiut,gl
# duplicate city: butaritari,ki
# city generated: san bartolome de tirajana,es
# processing request for san bartolome de tirajana,es
# duplicate city: saleaula,ws
# city generated: samusu,ws
# processing request for samusu,ws
# City not found...skipping.
#
# city generated: souillac,mu
# processing request for souillac,mu
# city generated: kapoeta,sd
# processing request for kapoeta,sd
# city generated: halalo,wf
# processing request for halalo,wf
# City not found...skipping.
#
# city generated: mayumba,ga
# processing request for mayumba,ga
# duplicate city: cape town,za
# city generated: camana,pe
# processing request for camana,pe
# duplicate city: yellowknife,ca
# city generated: ostrovnoy,ru
# processing request for ostrovnoy,ru
# city generated: oistins,bb
# processing request for oistins,bb
# city generated: cortez,us
# processing request for cortez,us
# duplicate city: bredasdorp,za
# city generated: the valley,ai
# processing request for the valley,ai
# duplicate city: hobart,au
# city generated: adamovka,ru
# processing request for adamovka,ru
# city generated: cap malheureux,mu
# processing request for cap malheureux,mu
# city generated: nouadhibou,mr
# processing request for nouadhibou,mr
# city generated: marawi,sd
# processing request for marawi,sd
# duplicate city: amderma,ru
# duplicate city: victoria,sc
# duplicate city: nanortalik,gl
# duplicate city: hithadhoo,mv
# city generated: paralimni,cy
# processing request for paralimni,cy
# city generated: hamilton,bm
# processing request for hamilton,bm
# duplicate city: new norfolk,au
# city generated: batagay,ru
# processing request for batagay,ru
# duplicate city: taolanaro,mg
# duplicate city: mar del plata,ar
# duplicate city: norman wells,ca
# duplicate city: ushuaia,ar
# city generated: vysokogornyy,ru
# processing request for vysokogornyy,ru
# city generated: wiarton,ca
# processing request for wiarton,ca
# city generated: saint george,bm
# processing request for saint george,bm
# duplicate city: nikolskoye,ru
# duplicate city: tumannyy,ru
# duplicate city: vaitupu,wf
# duplicate city: longyearbyen,sj
# duplicate city: taolanaro,mg
# city generated: college,us
# processing request for college,us
# duplicate city: albany,au
# duplicate city: tuktoyaktuk,ca
# duplicate city: kahului,us
# city generated: waddan,ly
# processing request for waddan,ly
# duplicate city: illoqqortoormiut,gl
# duplicate city: souillac,mu
# duplicate city: mys shmidta,ru
# city generated: nuuk,gl
# processing request for nuuk,gl
# duplicate city: attawapiskat,ca
# duplicate city: vardo,no
# duplicate city: mahebourg,mu
# duplicate city: okhotsk,ru
# city generated: haibowan,cn
# processing request for haibowan,cn
# City not found...skipping.
#
# duplicate city: cape town,za
# city generated: aranos,na
# processing request for aranos,na
# city generated: pierre,us
# processing request for pierre,us
# city generated: biak,id
# processing request for biak,id
# city generated: klaksvik,fo
# processing request for klaksvik,fo
# city generated: shediac,ca
# processing request for shediac,ca
# city generated: port hedland,au
# processing request for port hedland,au
# duplicate city: busselton,au
# duplicate city: punta arenas,cl
# duplicate city: puerto ayora,ec
# city generated: cazaje,ao
# processing request for cazaje,ao
# City not found...skipping.
#
# duplicate city: yellowknife,ca
# city generated: sharjah,ae
# processing request for sharjah,ae
# duplicate city: bathsheba,bb
# duplicate city: mataura,pf
# duplicate city: faanui,pf
# duplicate city: longyearbyen,sj
# city generated: kaitangata,nz
# processing request for kaitangata,nz
# city generated: vila franca do campo,pt
# processing request for vila franca do campo,pt
# duplicate city: yulara,au
# duplicate city: kapaa,us
# duplicate city: mys shmidta,ru
# city generated: lloydminster,ca
# processing request for lloydminster,ca
# city generated: nishihara,jp
# processing request for nishihara,jp
# city generated: venustiano carranza,mx
# processing request for venustiano carranza,mx
# duplicate city: rikitea,pf
# duplicate city: yellowknife,ca
# duplicate city: hobart,au
# duplicate city: ushuaia,ar
# city generated: sarh,td
# processing request for sarh,td
# duplicate city: butaritari,ki
# duplicate city: castro,cl
# city generated: telenesti,md
# processing request for telenesti,md
# city generated: murmashi,ru
# processing request for murmashi,ru
# duplicate city: lagoa,pt
# city generated: kualakapuas,id
# processing request for kualakapuas,id
# duplicate city: punta arenas,cl
# duplicate city: butaritari,ki
# city generated: sakakah,sa
# processing request for sakakah,sa
# duplicate city: mahebourg,mu
# city generated: komsomolskiy,ru
# processing request for komsomolskiy,ru
# city generated: xichang,cn
# processing request for xichang,cn
# duplicate city: ushuaia,ar
# duplicate city: constitucion,mx
# duplicate city: east london,za
# duplicate city: coihaique,cl
# duplicate city: busselton,au
# duplicate city: arraial do cabo,br
# duplicate city: cape town,za
# duplicate city: taolanaro,mg
# city generated: niamey,ne
# processing request for niamey,ne
# city generated: phetchaburi,th
# processing request for phetchaburi,th
# duplicate city: vaini,to
# duplicate city: ribeira grande,pt
# city generated: kantunilkin,mx
# processing request for kantunilkin,mx
# duplicate city: rikitea,pf
# duplicate city: bluff,nz
# duplicate city: saldanha,za
# duplicate city: mataura,pf
# duplicate city: qaanaaq,gl
# city generated: tabiauea,ki
# processing request for tabiauea,ki
# City not found...skipping.
#
# duplicate city: mataura,pf
# city generated: sao francisco,br
# processing request for sao francisco,br
# duplicate city: cape town,za
# city generated: waingapu,id
# processing request for waingapu,id
# city generated: moree,au
# processing request for moree,au
# duplicate city: vaini,to
# duplicate city: chumikan,ru
# duplicate city: ushuaia,ar
# duplicate city: ushuaia,ar
# duplicate city: rikitea,pf
# city generated: zagora,gr
# processing request for zagora,gr
# duplicate city: poum,nc
# duplicate city: illoqqortoormiut,gl
# city generated: rungata,ki
# processing request for rungata,ki
# City not found...skipping.
#
# duplicate city: road town,vg
# duplicate city: port elizabeth,za
# city generated: segovia,co
# processing request for segovia,co
# duplicate city: codrington,ag
# duplicate city: mys shmidta,ru
# duplicate city: arraial do cabo,br
# duplicate city: hithadhoo,mv
# duplicate city: chuy,uy
# city generated: tual,id
# processing request for tual,id
# duplicate city: vaini,to
# city generated: nome,us
# processing request for nome,us
# duplicate city: praia,cv
# duplicate city: hamilton,bm
# duplicate city: ushuaia,ar
# duplicate city: norman wells,ca
# duplicate city: taolanaro,mg
# duplicate city: caravelas,br
# city generated: khonuu,ru
# processing request for khonuu,ru
# City not found...skipping.
#
# duplicate city: esperance,au
# duplicate city: rio gallegos,ar
# duplicate city: hasaki,jp
# duplicate city: hobart,au
# duplicate city: vaini,to
# duplicate city: amderma,ru
# duplicate city: upernavik,gl
# duplicate city: rikitea,pf
# duplicate city: ushuaia,ar
# duplicate city: srednekolymsk,ru
# duplicate city: vaini,to
# duplicate city: belushya guba,ru
# city generated: taltal,cl
# processing request for taltal,cl
# duplicate city: rikitea,pf
# duplicate city: bambous virieux,mu
# duplicate city: mar del plata,ar
# city generated: najran,sa
# processing request for najran,sa
# duplicate city: bluff,nz
# duplicate city: airai,pw
# duplicate city: ahuimanu,us
# city generated: bongouanou,ci
# processing request for bongouanou,ci
# duplicate city: vaini,to
# city generated: leh,in
# processing request for leh,in
# duplicate city: albany,au
# duplicate city: yellowknife,ca
# duplicate city: mys shmidta,ru
# city generated: lazaro cardenas,mx
# processing request for lazaro cardenas,mx
# duplicate city: upernavik,gl
# city generated: cape coast,gh
# processing request for cape coast,gh
# city generated: batagay-alyta,ru
# processing request for batagay-alyta,ru
# duplicate city: upernavik,gl
# duplicate city: rikitea,pf
# city generated: port macquarie,au
# processing request for port macquarie,au
# city generated: narsaq,gl
# processing request for narsaq,gl
# duplicate city: hilo,us
# city generated: isangel,vu
# processing request for isangel,vu
# duplicate city: yar-sale,ru
# city generated: nemuro,jp
# processing request for nemuro,jp
# duplicate city: port elizabeth,za
# city generated: nizhniy tsasuchey,ru
# processing request for nizhniy tsasuchey,ru
# duplicate city: cayenne,gf
# duplicate city: thompson,ca
# city generated: laredo,us
# processing request for laredo,us
# city generated: benguela,ao
# processing request for benguela,ao
# duplicate city: butaritari,ki
# duplicate city: bethel,us
# duplicate city: punta arenas,cl
# duplicate city: cape town,za
# duplicate city: busselton,au
# duplicate city: busselton,au
# duplicate city: vaini,to
# duplicate city: busselton,au
# duplicate city: saskylakh,ru
# duplicate city: hobart,au
# duplicate city: rikitea,pf
# city generated: sinnar,in
# processing request for sinnar,in
# city generated: ust-ishim,ru
# processing request for ust-ishim,ru
# duplicate city: bluff,nz
# city generated: killarney,ca
# processing request for killarney,ca
# city generated: itarema,br
# processing request for itarema,br
# duplicate city: samusu,ws
# duplicate city: ushuaia,ar
# city generated: gangotri,in
# processing request for gangotri,in
# City not found...skipping.
#
# duplicate city: ribeira grande,pt
# duplicate city: khatanga,ru
# city generated: aginskoye,ru
# processing request for aginskoye,ru
# duplicate city: saleaula,ws
# duplicate city: hobart,au
# duplicate city: caravelas,br
# duplicate city: dikson,ru
# duplicate city: hobart,au
# duplicate city: nikolskoye,ru
# duplicate city: rikitea,pf
# city generated: luanda,ao
# processing request for luanda,ao
# city generated: bangui,ph
# processing request for bangui,ph
# duplicate city: jamestown,sh
# duplicate city: saskylakh,ru
# duplicate city: hermanus,za
# duplicate city: busselton,au
# duplicate city: mataura,pf
# duplicate city: cape town,za
# duplicate city: mataura,pf
# duplicate city: mataura,pf
# duplicate city: ushuaia,ar
# duplicate city: ushuaia,ar
# duplicate city: busselton,au
# duplicate city: qaanaaq,gl
# duplicate city: bluff,nz
# duplicate city: busselton,au
# duplicate city: georgetown,sh
# duplicate city: ushuaia,ar
# duplicate city: constitucion,mx
# city generated: rawa mazowiecka,pl
# processing request for rawa mazowiecka,pl
# duplicate city: ilulissat,gl
# duplicate city: taolanaro,mg
# duplicate city: salalah,om
# duplicate city: busselton,au
# city generated: chicama,pe
# processing request for chicama,pe
# duplicate city: kapaa,us
# duplicate city: torbay,ca
# duplicate city: taolanaro,mg
# city generated: shubarshi,kz
# processing request for shubarshi,kz
# city generated: yirol,sd
# processing request for yirol,sd
# City not found...skipping.
#
# duplicate city: atuona,pf
# city generated: japura,br
# processing request for japura,br
# duplicate city: castro,cl
# duplicate city: tsihombe,mg
# duplicate city: busselton,au
# city generated: labutta,mm
# processing request for labutta,mm
# City not found...skipping.
#
# city generated: khuchni,ru
# processing request for khuchni,ru
# duplicate city: new norfolk,au
# duplicate city: barentsburg,sj
# duplicate city: saint-philippe,re
# city generated: nelidovo,ru
# processing request for nelidovo,ru
# duplicate city: saldanha,za
# duplicate city: comodoro rivadavia,ar
# city generated: avera,pf
# processing request for avera,pf
# duplicate city: chicama,pe
# duplicate city: henties bay,na
# city generated: terney,ru
# processing request for terney,ru
# city generated: kavieng,pg
# processing request for kavieng,pg
# duplicate city: souillac,mu
# duplicate city: punta arenas,cl
# duplicate city: kapaa,us
# city generated: tiarei,pf
# processing request for tiarei,pf
# city generated: kangaatsiaq,gl
# processing request for kangaatsiaq,gl
# duplicate city: lebu,cl
# duplicate city: atuona,pf
# duplicate city: rikitea,pf
# duplicate city: nizhniy tsasuchey,ru
# city generated: porto novo,cv
# processing request for porto novo,cv
# city generated: pingzhuang,cn
# processing request for pingzhuang,cn
# duplicate city: port alfred,za
# duplicate city: mataura,pf
# city generated: skalistyy,ru
# processing request for skalistyy,ru
# City not found...skipping.
#
# duplicate city: illoqqortoormiut,gl
# duplicate city: bredasdorp,za
# duplicate city: nuuk,gl
# duplicate city: ilulissat,gl
# duplicate city: ushuaia,ar
# city generated: turochak,ru
# processing request for turochak,ru
# duplicate city: longyearbyen,sj
# duplicate city: komsomolskiy,ru
# duplicate city: hermanus,za
# duplicate city: qaanaaq,gl
# duplicate city: vaini,to
# duplicate city: mataura,pf
# duplicate city: barentsburg,sj
# city generated: sobolevo,ru
# processing request for sobolevo,ru
# duplicate city: tsihombe,mg
# city generated: bac lieu,vn
# processing request for bac lieu,vn
# duplicate city: lebu,cl
# duplicate city: mataura,pf
# duplicate city: geraldton,au
# duplicate city: dharchula,in
# duplicate city: rikitea,pf
# city generated: ximei,cn
# processing request for ximei,cn
# duplicate city: umm lajj,sa
# city generated: georgetown,us
# processing request for georgetown,us
# ****************************************
# End of Data Retrieval

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print(len(cities_name))
# Out:
# 500

# %%
print(len(duplicate_cities))
# Out:
# 670

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Zip all lists together into tuples
city_ID = list(range(len(cities_name)))
weather_zip = zip(city_ID, cities_name, countries, dates, humidities, latitudes, longititudes, max_temps, clouds, wind_speeds)

# # # save the output file path "ISO-8859-1"
output_file = os.path.join("cities.csv")
 
# #  open the output file, create a header row, and then write the zipped object to the csv
with open(output_file, "w", encoding='utf-8') as datafile:
    writer = csv.writer(datafile)
    writer.writerow(["City_ID", "City", "Country","Date", "Humidity", "Lat", "Long", "Max Temp(F)","Cloudiness", "Wind Speed"])
    writer.writerows(weather_zip)

# %%
file = os.path.join("cities.csv")
weather_df = pd.read_csv(file, encoding= 'utf-8')

weather_df.head(30)
# Out:
#     City_ID           City Country        Date  Humidity    Lat    Long  \
# 0         0    Port Alfred      ZA  1600317909        75 -33.59   26.89
# 1         1        Rikitea      PF  1600317910        84 -23.12 -134.97
# 2         2          Ancud      CL  1600317910        85 -41.87  -73.82
# 3         3        Mataura      NZ  1600317910        84 -46.19  168.86
# 4         4    New Norfolk      AU  1600317910        52 -42.78  147.06
# 5         5  Mount Gambier      AU  1600317679        76 -37.83  140.77
# 6         6      Caravelas      BR  1600317911        87 -17.71  -39.25
# 7         7           Rome      US  1600317675        76  43.21  -75.46
# 8         8  Mar del Plata      AR  1600317838        93 -38.00  -57.56
# 9         9      Cape Town      ZA  1600317911       100 -33.93   18.42
# 10       10    Grand Forks      US  1600317912        65  47.93  -97.03
# 11       11       Tucupita      VE  1600317912        97   9.06  -62.05
# 12       12          Kapaa      US  1600317912        65  22.08 -159.32
# 13       13        Qaanaaq      GL  1600317912        75  77.48  -69.36
# 14       14         Padang      ID  1600317912        62  -0.95  100.35
# 15       15        Atbasar      KZ  1600317913        73  51.80   68.33
# 16       16   Punta Arenas      CL  1600317883        86 -53.15  -70.92
# 17       17         Barrow      US  1600317913        81  71.29 -156.79
# 18       18    Tuktoyaktuk      CA  1600317913        87  69.45 -133.04
# 19       19          Zemio      CF  1600317914        93   5.03   25.14
# 20       20     San Rafael      AR  1600317710        34 -34.62  -68.33
# 21       21          Simao      CN  1600317914        55  22.79  100.97
# 22       22           Esim      GH  1600317914        89   4.87   -2.24
# 23       23   Fort Collins      US  1600317900        62  40.59 -105.08
# 24       24  San Cristobal      VE  1600317915        91   7.77  -72.22
# 25       25          Tupik      RU  1600317915        58  54.43  119.93
# 26       26         Hobart      AU  1600317727        43 -42.88  147.33
# 27       27       Araouane      ML  1600317915        14  18.90   -3.53
# 28       28          Bluff      NZ  1600317916        84 -46.60  168.33
# 29       29       Alegrete      BR  1600317916        92 -29.78  -55.79
#
#     Max Temp(F)  Cloudiness  Wind Speed
# 0         13.94           1        6.15
# 1         22.62          29        8.98
# 2         10.56         100        1.79
# 3          6.67         100        7.15
# 4         14.44          16        1.34
# 5         14.00          90        8.20
# 6         19.60           1        1.83
# 7         13.00           1        3.10
# 8          8.33          90        2.60
# 9         10.00          90        2.60
# 10         7.00          40        2.10
# 11        23.33          95        0.81
# 12        28.00          40        4.10
# 13        -8.55           0        2.86
# 14        29.65          41        3.12
# 15        10.48         100        8.12
# 16         4.00         100        7.20
# 17         9.00          90        4.10
# 18         6.00          90        3.10
# 19        21.31          53        0.29
# 20        15.53           5        3.83
# 21        28.40          53        1.17
# 22        23.80          88        4.55
# 23        14.44           1        1.50
# 24        17.78          69        0.81
# 25        12.64         100        5.53
# 26        14.44          40        5.70
# 27        33.06           7        5.99
# 28         6.67          98        7.15
# 29        13.35          51        1.71

# %%
weather_df.describe()
# Out:
#           City_ID          Date    Humidity        Lat        Long  \
# count  500.000000  5.000000e+02  500.000000  500.00000  500.000000
# mean   249.500000  1.600318e+09   72.136000   20.02636   14.527000
# std    144.481833  7.859351e+01   20.887366   32.96459   92.230133
# min      0.000000  1.600318e+09    2.000000  -54.80000 -179.170000
# 25%    124.750000  1.600318e+09   62.000000   -7.15500  -69.255000
# 50%    249.500000  1.600318e+09   77.000000   22.60000   18.485000
# 75%    374.250000  1.600318e+09   87.000000   47.44750  100.340000
# max    499.000000  1.600318e+09  100.000000   78.22000  179.320000
#
#        Max Temp(F)  Cloudiness  Wind Speed
# count   500.000000  500.000000   500.00000
# mean     19.044300   54.532000     3.75810
# std       8.347869   38.036489     2.54329
# min      -8.550000    0.000000     0.17000
# 25%      13.000000   16.750000     1.78750
# 50%      19.460000   67.000000     3.10000
# 75%      26.000000   90.000000     5.27500
# max      38.440000  100.000000    17.00000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_city_data = weather_df[weather_df["Humidity"] <= 100]
clean_city_data = clean_city_data.reset_index(drop=True)
clean_city_data.describe()
# Out:
#           City_ID          Date    Humidity        Lat        Long  \
# count  500.000000  5.000000e+02  500.000000  500.00000  500.000000
# mean   249.500000  1.600318e+09   72.136000   20.02636   14.527000
# std    144.481833  7.859351e+01   20.887366   32.96459   92.230133
# min      0.000000  1.600318e+09    2.000000  -54.80000 -179.170000
# 25%    124.750000  1.600318e+09   62.000000   -7.15500  -69.255000
# 50%    249.500000  1.600318e+09   77.000000   22.60000   18.485000
# 75%    374.250000  1.600318e+09   87.000000   47.44750  100.340000
# max    499.000000  1.600318e+09  100.000000   78.22000  179.320000
#
#        Max Temp(F)  Cloudiness  Wind Speed
# count   500.000000  500.000000   500.00000
# mean     19.044300   54.532000     3.75810
# std       8.347869   38.036489     2.54329
# min      -8.550000    0.000000     0.17000
# 25%      13.000000   16.750000     1.78750
# 50%      19.460000   67.000000     3.10000
# 75%      26.000000   90.000000     5.27500
# max      38.440000  100.000000    17.00000

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
clean_city_data.plot.scatter(x='Lat',
                      y='Max Temp(F)',
                      c='RoyalBlue', marker="o", edgecolors="black", s = 40,  alpha=0.8, grid = True)

plt.title('City Latitude vs. Maximum Temperature')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature(F)')
# Out:
# Text(0, 0.5, 'Maximum Temperature(F)')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
clean_city_data.plot.scatter(x='Lat',
                      y='Humidity',
                      c='RoyalBlue', marker="o", edgecolors="black", s = 40,  alpha=0.8, grid = True)

plt.title('Latitude vs. Humidity ')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
# Out:
# Text(0, 0.5, 'Humidity')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clean_city_data.plot.scatter(x='Lat',
                      y='Cloudiness',
                      c='RoyalBlue', marker="o", edgecolors="black", s = 40,  alpha=0.8, grid = True)

plt.title('Latitude vs. Cloudiness ')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
# Out:
# Text(0, 0.5, 'Cloudiness')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
clean_city_data.plot.scatter(x='Lat',
                      y='Wind Speed',
                      c='RoyalBlue', marker="o", edgecolors="black", s = 40,  alpha=0.8, grid = True)

plt.title('Latitude vs. Wind Speed ')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
# Out:
# Text(0, 0.5, 'Wind Speed')

# %% [markdown]
# ## Linear Regression

# %%
north_hemi = clean_city_data[clean_city_data["Lat"] > 0]
north_hemi = north_hemi.reset_index(drop=True)
north_hemi.head(20)
# Out:
#     City_ID           City Country        Date  Humidity    Lat    Long  \
# 0         7           Rome      US  1600317675        76  43.21  -75.46
# 1        10    Grand Forks      US  1600317912        65  47.93  -97.03
# 2        11       Tucupita      VE  1600317912        97   9.06  -62.05
# 3        12          Kapaa      US  1600317912        65  22.08 -159.32
# 4        13        Qaanaaq      GL  1600317912        75  77.48  -69.36
# 5        15        Atbasar      KZ  1600317913        73  51.80   68.33
# 6        17         Barrow      US  1600317913        81  71.29 -156.79
# 7        18    Tuktoyaktuk      CA  1600317913        87  69.45 -133.04
# 8        19          Zemio      CF  1600317914        93   5.03   25.14
# 9        21          Simao      CN  1600317914        55  22.79  100.97
# 10       22           Esim      GH  1600317914        89   4.87   -2.24
# 11       23   Fort Collins      US  1600317900        62  40.59 -105.08
# 12       24  San Cristobal      VE  1600317915        91   7.77  -72.22
# 13       25          Tupik      RU  1600317915        58  54.43  119.93
# 14       27       Araouane      ML  1600317915        14  18.90   -3.53
# 15       31       La Sarre      CA  1600317917        97  48.80  -79.20
# 16       32   Forsytheganj      BY  1600317917        75  52.63   29.73
# 17       33          Latur      IN  1600317918        75  18.40   76.58
# 18       35         Albany      US  1600317877        76  42.60  -73.97
# 19       37    Germersheim      DE  1600317918        63  49.22    8.36
#
#     Max Temp(F)  Cloudiness  Wind Speed
# 0         13.00           1        3.10
# 1          7.00          40        2.10
# 2         23.33          95        0.81
# 3         28.00          40        4.10
# 4         -8.55           0        2.86
# 5         10.48         100        8.12
# 6          9.00          90        4.10
# 7          6.00          90        3.10
# 8         21.31          53        0.29
# 9         28.40          53        1.17
# 10        23.80          88        4.55
# 11        14.44           1        1.50
# 12        17.78          69        0.81
# 13        12.64         100        5.53
# 14        33.06           7        5.99
# 15        -1.99          43        2.13
# 16        16.47         100        5.01
# 17        28.12          68        4.22
# 18        15.00          17        1.43
# 19        17.78          27        4.04

# %%
south_hemi = clean_city_data[clean_city_data["Lat"] < 0]
south_hemi = south_hemi.reset_index(drop=True)
south_hemi.head(20)
# Out:
#     City_ID           City Country        Date  Humidity    Lat    Long  \
# 0         0    Port Alfred      ZA  1600317909        75 -33.59   26.89
# 1         1        Rikitea      PF  1600317910        84 -23.12 -134.97
# 2         2          Ancud      CL  1600317910        85 -41.87  -73.82
# 3         3        Mataura      NZ  1600317910        84 -46.19  168.86
# 4         4    New Norfolk      AU  1600317910        52 -42.78  147.06
# 5         5  Mount Gambier      AU  1600317679        76 -37.83  140.77
# 6         6      Caravelas      BR  1600317911        87 -17.71  -39.25
# 7         8  Mar del Plata      AR  1600317838        93 -38.00  -57.56
# 8         9      Cape Town      ZA  1600317911       100 -33.93   18.42
# 9        14         Padang      ID  1600317912        62  -0.95  100.35
# 10       16   Punta Arenas      CL  1600317883        86 -53.15  -70.92
# 11       20     San Rafael      AR  1600317710        34 -34.62  -68.33
# 12       26         Hobart      AU  1600317727        43 -42.88  147.33
# 13       28          Bluff      NZ  1600317916        84 -46.60  168.33
# 14       29       Alegrete      BR  1600317916        92 -29.78  -55.79
# 15       30          Airai      TL  1600317630        50  -8.93  125.41
# 16       34       Oxapampa      PE  1600317918        82 -10.58  -75.40
# 17       36      Carnarvon      AU  1600317918        18 -24.87  113.63
# 18       39   Richards Bay      ZA  1600317700        71 -28.78   32.04
# 19       43     Uruguaiana      BR  1600317885        93 -29.75  -57.09
#
#     Max Temp(F)  Cloudiness  Wind Speed
# 0         13.94           1        6.15
# 1         22.62          29        8.98
# 2         10.56         100        1.79
# 3          6.67         100        7.15
# 4         14.44          16        1.34
# 5         14.00          90        8.20
# 6         19.60           1        1.83
# 7          8.33          90        2.60
# 8         10.00          90        2.60
# 9         29.65          41        3.12
# 10         4.00         100        7.20
# 11        15.53           5        3.83
# 12        14.44          40        5.70
# 13         6.67          98        7.15
# 14        13.35          51        1.71
# 15        24.80          92        1.58
# 16        14.44          91        1.18
# 17        28.00           0        6.70
# 18        19.48          42        5.42
# 19        17.00          53        1.00

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
from scipy.stats import linregress
from sklearn import datasets
import scipy.stats as sts

correlation = sts.pearsonr(north_hemi['Lat'], north_hemi['Max Temp(F)'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is -0.81
# The p-value is 1.144702980193723e-81

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(north_hemi['Lat'], north_hemi['Max Temp(F)'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = north_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(north_hemi['Lat'],  north_hemi['Max Temp(F)'])

# Plot the regression line
plt.plot(north_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (10, 0), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp(F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.6557865620245418

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(south_hemi['Lat'], south_hemi['Max Temp(F)'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.73
# The p-value is 1.3417755489641275e-26

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(south_hemi['Lat'], south_hemi['Max Temp(F)'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = south_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(south_hemi['Lat'],  south_hemi['Max Temp(F)'])

# Plot the regression line
plt.plot(south_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50, 25), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp(F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5285458696189261

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(north_hemi['Lat'], north_hemi['Humidity'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is -0.02
# The p-value is 0.6440430025451976

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(north_hemi['Lat'], north_hemi['Humidity'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = north_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(north_hemi['Lat'],  north_hemi['Humidity'])

# Plot the regression line
plt.plot(north_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (10, 30), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0006213298448124323

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(south_hemi['Lat'], south_hemi['Humidity'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.02
# The p-value is 0.7736174098487903

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(south_hemi['Lat'], south_hemi['Humidity'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = south_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(south_hemi['Lat'],  south_hemi['Humidity'])

# Plot the regression line
plt.plot(south_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50, 25), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0005459894967803455

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(north_hemi['Lat'], north_hemi['Cloudiness'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.1
# The p-value is 0.07632064713937825

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(north_hemi['Lat'], north_hemi['Cloudiness'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = north_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(north_hemi['Lat'],  north_hemi['Cloudiness'])

# Plot the regression line
plt.plot(north_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (10, 30), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.009104028423527024

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(south_hemi['Lat'], south_hemi['Cloudiness'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is -0.09
# The p-value is 0.27850271882463473

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(south_hemi['Lat'], south_hemi['Cloudiness'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = south_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(south_hemi['Lat'],  south_hemi['Cloudiness'])

# Plot the regression line
plt.plot(south_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50, 25), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.007721670035622531

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(north_hemi['Lat'], north_hemi['Wind Speed'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.18
# The p-value is 0.0010659810706846985

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(north_hemi['Lat'], north_hemi['Wind Speed'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = north_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(north_hemi['Lat'],  north_hemi['Wind Speed'])

# Plot the regression line
plt.plot(north_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (10, 8), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.030695876019239527

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
correlation = sts.pearsonr(south_hemi['Lat'], south_hemi['Wind Speed'])

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is -0.21
# The p-value is 0.008634132051722655

# %%
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(south_hemi['Lat'], south_hemi['Wind Speed'])

# Calculate the predictions for each value of x (# Rooms)
regression_values = south_hemi['Lat'] * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(south_hemi['Lat'],  south_hemi['Wind Speed'])

# Plot the regression line
plt.plot(south_hemi['Lat'], regression_values, "red")

# Annotate the plot with the linear equation
plt.annotate(line_eq, (-50 ,15), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04450316191482271
